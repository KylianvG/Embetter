# %% [markdown]
# ## Hands-on Tutorial: Quantifying and Reducing Gender Stereotypes in Word Embeddings

# %% [markdown]
# Ensuring fairness in algorithmically-driven decision-making is important to avoid inadvertent cases of bias and perpetuation of harmful stereotypes. However, modern natural language processing techniques, which learn model parameters based on data, might rely on implicit biases presented in the data to make undesirable stereotypical associations. Such a danger is facing us with word embedding, a popular framework to represent text data as vectors which has been used in many machine learning and natural language processing tasks. Recent results ([1](https://arxiv.org/abs/1607.06520), [2](https://arxiv.org/abs/1608.07187)) show that even word embeddings trained on Google News articles exhibit female/male gender stereotypes to a disturbing extent. This raises concerns because of their widespread use, as we describe, often tends to amplify these biases.
#
# In the following, we provide step-by-step instructions to demonstrate and quanitfy the biases in word embedding.

# %%
# Setup:
# Clone the code repository from https://github.com/tolga-b/debiaswe.git
# mkdir debiaswe_tutorial
# cd debiaswe_tutorial
# git clone https://github.com/tolga-b/debiaswe.git

# To reduce the time of downloading data, we provide as subset of GoogleNews-vectors in the following location:
# https://drive.google.com/file/d/1NH6jcrg8SXbnhpIXRIXF_-KUE7wGxGaG/view?usp=sharing

# For full embeddings:
# Download embeddings at https://github.com/tolga-b/debiaswe and put them on the following directory
# embeddings/GoogleNews-vectors-negative300-hard-debiased.bin
# embeddings/GoogleNews-vectors-negative300.bin

# %%
from __future__ import print_function, division
# %matplotlib inline
from matplotlib import pyplot as plt
import json
import random
import numpy as np

import debiaswe as dwe
import debiaswe.we as we
from debiaswe.we import WordEmbedding
from debiaswe.data import load_professions

# %% [markdown]
# ## Part 1: Gender Bias in Word Embedding
#
#
# ### Step 1: Load data
# We first load the word embedding trained on a corpus of Google News texts consisting of 3 million English words and terms. The embedding maps each word into a 300-dimension vector.

# %%
# load xlnet generated word embeddings
E = WordEmbedding('./embeddings/xlnet_specials.csv')

# load professions
professions = load_professions()
profession_words = [p[0] for p in professions]
# Out:
# *** Reading data from ./embeddings/xlnet_specials.csv
# (26423, 768)
# 26423 words of dimension 768 : in, for, that, is, ..., Jay, Leroy, Brad, Jermaine
# Loaded professions
# Format:
# word,
# definitional female -1.0 -> definitional male 1.0
# stereotypical female -1.0 -> stereotypical male 1.0

# %%
# Extra test cell, remove later
print(np.linalg.norm(E.vecs, axis=1).mean())
print(E.vecs.mean())

from sklearn.manifold import TSNE
tsne = TSNE(n_components=2).fit_transform(E.vecs[:2000])
plt.scatter(tsne[:,0], tsne[:,1], s=10)
plt.show()
# Out:
# 130.15578
# 0.0757519

# %% [markdown]
# ### Step 2: Define gender direction
#
# We define gender direction by the direciton of she - he because they are frequent and do not have fewer alternative word senses (e.g., man can also refer to mankind). In the paper, we discuss alternative approach for defining gender direction (e.g., using PCA).

# %%
# gender direction
v_gender = E.diff('she', 'he')

# %% [markdown]
# ### Step 3: Generating analogies of "Man: x :: Woman : y"
#
# We show that the word embedding model generates gender-streotypical analogy pairs.
# To generate the analogy pairs, we use the analogy score defined in our paper. This score finds word pairs that are well aligned with gender direction as well as within a short distance from each other to preserve topic consistency.

# %%
# analogies gender
a_gender = E.best_analogies_dist_thresh(v_gender, max_words=3000, thresh=0.1)

# for (a,b,c) in a_gender:
#     print(a+"-"+b)
we.viz(a_gender)
# Out:
# Computing neighbors
# Mean: 49.16266666666667
# Median: 0.0
# (73744, 768)
#    0                     schedule | re                           0.27
#    1                international | joining                      0.26
#    2                       answer | grant                        0.25
#    3                      website | percentage                   0.24
#    4                         call | minute                       0.22
#    5                     province | age                          0.22
#    6                         game | activists                    0.22
#    7                      station | income                       0.21
#    8                      calling | members                      0.21
#    9                    beautiful | perfect                      0.21
#   10                       sister | brother                      0.21
#   11                     expected | easily                       0.20
#   12                          web | premium                      0.20
#   13                       campus | fairly                       0.20
#   14                      returns | returning                    0.20
#   15                         that | performance                  0.20
#   16                         name | violations                   0.19
#   17                         fast | especially                   0.19
#   18                         seat | minutes                      0.19
#   19                   originally | obligation                   0.19
#   20                         mail | purchased                    0.19
#   21                        field | fields                       0.19
#   22                  appointment | representative               0.19
#   23                       career | regularly                    0.19
#   24                   integrated | registration                 0.18
#   25                      adopted | highest                      0.18
#   26                         life | most                         0.18
#   27                      quarter | guilty                       0.18
#   28                         gift | purchase                     0.18
#   29                      correct | prices                       0.18
#   30                       formal | membership                   0.18
#   31                        email | funded                       0.17
#   32                      seeking | member                       0.17
#   33                        match | point                        0.17
#   34                       strike | participation                0.17
#   35                         base | source                       0.17
#   36                           me | us                           0.17
#   37                        value | information                  0.17
#   38                     southern | northern                     0.17
#   39                    exclusive | only                         0.17
#   40                     official | senior                       0.17
#   41                    condition | situation                    0.17
#   42                        hotel | reserve                      0.17
#   43                  anticipated | maximum                      0.16
#   44                          die | can                          0.16
#   45                     articles | attention                    0.16
#   46                     multiple | per                          0.16
#   47                        sharp | excellent                    0.16
#   48                         much | definitely                   0.16
#   49                         site | section                      0.16
#   50                       follow | winner                       0.16
#   51                         fire | provides                     0.16
#   52                     question | interview                    0.16
#   53                         file | all                          0.16
#   54                     exciting | innovative                   0.16
#   55                        peace | best                         0.16
#   56                         nice | normal                       0.15
#   57                     employee | officer                      0.15
#   58                        black | white                        0.15
#   59                        south | essential                    0.15
#   60                         late | guide                        0.15
#   61                        music | recording                    0.15
#   62                         star | role                         0.15
#   63                      student | parent                       0.15
#   64                        steel | leader                       0.15
#   65                         suit | action                       0.15
#   66                       listed | sale                         0.15
#   67                       design | however                      0.15
#   68                        money | time                         0.15
#   69                      singles | product                      0.15
#   70                  alternative | thanks                       0.15
#   71                         boat | home                         0.15
#   72                      version | amount                       0.14
#   73                       please | immediate                    0.14
#   74                     recovery | analysis                     0.14
#   75                       degree | minority                     0.14
#   76                        check | quite                        0.14
#   77                       tennis | visit                        0.14
#   78                         yard | at                           0.14
#   79                      college | probably                     0.14
#   80                    touchdown | touchdowns                   0.14
#   81                         west | east                         0.14
#   82                       finish | plenty                       0.14
#   83                          bad | worst                        0.14
#   84                         hard | work                         0.14
#   85                 professional | sending                      0.14
#   86                  acquisition | competitive                  0.14
#   87                         long | very                         0.13
#   88                       ground | quickly                      0.13
#   89                        means | earned                       0.13
#   90                         mean | resident                     0.13
#   91                         type | types                        0.13
#   92                      package | size                         0.13
#   93                         rate | photo                        0.13
#   94                      whether | selected                     0.13
#   95                       murder | blood                        0.13
#   96                         loan | charge                       0.13
#   97                     business | disease                      0.13
#   98                       people | person                       0.13
#   99                   exhibition | fee                          0.13
#  100                      company | share                        0.13
#  101                         view | motion                       0.13
#  102                       engine | quality                      0.13
#  103                        hoped | hopes                        0.13
#  104                    estimates | estimate                     0.13
#  105                     delivery | mixed                        0.12
#  106                      special | limited                      0.12
#  107                        seven | five                         0.12
#  108                       energy | status                       0.12
#  109                          end | result                       0.12
#  110                     mortgage | difference                   0.12
#  111                   associated | position                     0.12
#  112                        night | year                         0.12
#  113                     internet | processing                   0.12
#  114                   qualifying | qualify                      0.12
#  115                      violent | unique                       0.12
#  116                      looking | look                         0.12
#  117                         into | points                       0.12
#  118                      brought | taken                        0.12
#  119                          fan | personal                     0.12
#  120                     location | material                     0.12
#  121                        order | right                        0.11
#  122                       relief | lowest                       0.11
#  123                      article | recession                    0.11
#  124                      economy | inflation                    0.11
#  125                          air | every                        0.11
#  126                       online | greater                      0.11
#  127                      theater | movie                        0.11
#  128                   historical | historic                     0.11
#  129                      release | opportunity                  0.11
#  130                         home | draw                         0.11
#  131                         date | spot                         0.11
#  132                    selection | improved                     0.11
#  133                        sleep | over                         0.11
#  134                      created | made                         0.11
#  135                         arms | arm                          0.11
#  136                       annual | total                        0.11
#  137                      feature | middle                       0.11
#  138                  recognition | experienced                  0.11
#  139                         code | inch                         0.11
#  140                    ownership | owner                        0.11
#  141                         week | unemployment                 0.11
#  142                        style | protesters                   0.11
#  143                         sets | setting                      0.11
#  144                   assessment | cultural                     0.11
#  145                          dog | box                          0.11
#  146                        board | cell                         0.11
#  147                     resource | appropriate                  0.11
#  148                       strong | weak                         0.11
#  149                         line | credit                       0.11
#  150                       season | unlikely                     0.11
#  151                        cause | better                       0.11
#  152                         love | loved                        0.11
#  153                      operate | operating                    0.11
#  154                           pm | quarterly                    0.10
#  155                        print | another                      0.10
#  156                     intended | hurt                         0.10
#  157                         care | seriously                    0.10
#  158                  interesting | unusual                      0.10
#  159                     practice | cash                         0.10
#  160                       effect | affected                     0.10
#  161                     provided | above                        0.10
#  162                        issue | foot                         0.10
#  163                        ready | pleased                      0.10
#  164                        saves | save                         0.10
#  165                      address | properties                   0.10
#  166                       market | score                        0.10
#  167                         core | top                          0.10
#  168                         want | wanted                       0.10
#  169                          job | body                         0.10
#  170                      awarded | claim                        0.10
#  171                        theme | featured                     0.10
#  172                      central | common                       0.10
#  173                        aware | mind                         0.10
#  174                         free | happy                        0.10
#  175                         path | direction                    0.10
#  176                         runs | goals                        0.10
#  177                         rest | once                         0.10
#  178                        after | twice                        0.10
#  179                       mother | father                       0.10
#  180                        heart | reasons                      0.10
#  181                     strategy | valuable                     0.10
#  182                         fine | dispute                      0.10
#  183                         drop | no                           0.10
#  184                      holiday | pain                         0.09
#  185                      process | image                        0.09
#  186                         held | hold                         0.09
#  187                       number | times                        0.09
#  188                     visitors | friendly                     0.09
#  189                         girl | plants                       0.09
#  190                      degrees | worse                        0.09
#  191                      license | male                         0.09
#  192                         days | weeks                        0.09
#  193                    education | educational                  0.09
#  194                         fall | falling                      0.09
#  195                         sort | kind                         0.09
#  196                        focus | anything                     0.09
#  197                      offense | chance                       0.09
#  198                         eyes | seats                        0.09
#  199                       ballot | vote                         0.09
#  200                        extra | additional                   0.09
#  201                       runner | runners                      0.09
#  202                        names | name                         0.09
#  203                      banking | grade                        0.09
#  204                      changed | changes                      0.09
#  205                  consecutive | again                        0.09
#  206                         body | balance                      0.09
#  207                         mile | distance                     0.09
#  208                    insurance | cards                        0.09
#  209                     exposure | activity                     0.09
#  210                         year | years                        0.09
#  211                        round | around                       0.09
#  212                          net | pressure                     0.09
#  213                     bringing | bring                        0.09
#  214                       become | full                         0.09
#  215                          law | likely                       0.09
#  216              law_enforcement | left                         0.09
#  217                   conference | media                        0.09
#  218                         rain | based                        0.09
#  219                        broke | breaking                     0.09
#  220                          run | already                      0.08
#  221                        class | head                         0.08
#  222                 championship | contest                      0.08
#  223                       brands | brand                        0.08
#  224                       travel | products                     0.08
#  225                         cold | law                          0.08
#  226                         east | north                        0.08
#  227                      outside | receive                      0.08
#  228                     directed | caused                       0.08
#  229                         race | choice                       0.08
#  230                         easy | poverty                      0.08
#  231                         rule | about                        0.08
#  232                      percent | readers                      0.08
#  233                        north | except                       0.08
#  234                         blue | red                          0.08
#  235                     producer | request                      0.08
#  236                       attack | privacy                      0.08
#  237                       street | floor                        0.08
#  238                     attacked | attack                       0.08
#  239                   commercial | agreement                    0.08
#  240                       easier | harder                       0.08
#  241                         post | posted                       0.08
#  242                        short | now                          0.08
#  243                       search | even                         0.08
#  244                  engineering | professionals                0.08
#  245                       thinks | thinking                     0.08
#  246                     function | edition                      0.08
#  247                         join | joined                       0.08
#  248                     clinical | efficient                    0.08
#  249                     claiming | agent                        0.08
#  250                 neighborhood | monthly                      0.08
#  251                      service | space                        0.08
#  252                      lending | both                         0.08
#  253                         help | helped                       0.08
#  254                         tell | told                         0.08
#  255                     solution | plant                        0.08
#  256                     planning | plan                         0.08
#  257                          bed | college                      0.08
#  258                    excellent | significantly                0.08
#  259                         ball | pick                         0.08
#  260                      against | positive                     0.08
#  261                       dollar | page                         0.08
#  262                         baby | mistake                      0.08
#  263                        feels | take                         0.08
#  264                        video | social                       0.08
#  265                      claimed | different                    0.08
#  266                         loss | sales                        0.08
#  267                      patient | movement                     0.08
#  268                        glass | wine                         0.08
#  269                  educational | wrong                        0.07
#  270                     included | includes                     0.07
#  271                         area | payment                      0.07
#  272                          got | getting                      0.07
#  273                      machine | stress                       0.07
#  274                     specific | also                         0.07
#  275                         auto | damage                       0.07
#  276                        chose | chosen                       0.07
#  277                        offer | price                        0.07
#  278                     increase | increased                    0.07
#  279                       covers | cover                        0.07
#  280                      defined | extended                     0.07
#  281                comprehensive | international                0.07
#  282                     addition | handle                       0.07
#  283                       losing | lose                         0.07
#  284                      leaving | leave                        0.07
#  285                      qualify | from                         0.07
#  286                     becoming | per_cent                     0.07
#  287                        blame | mainly                       0.07
#  288                           am | was                          0.07
#  289                     previous | previously                   0.07
#  290                      dispute | struggling                   0.07
#  291                    qualified | prompted                     0.07
#  292                          far | as                           0.07
#  293                         bank | park                         0.07
#  294                     hundreds | dozens                       0.07
#  295                         four | three                        0.07
#  296                     returned | explained                    0.07
#  297                         turn | turning                      0.07
#  298                         look | looks                        0.07
#  299                      started | beginning                    0.07
#  300                       weight | part                         0.07
#  301                     designed | pre                          0.07
#  302                        learn | learning                     0.07
#  303                       proven | proved                       0.07
#  304                        block | account                      0.07
#  305                         song | songs                        0.07
#  306                       vision | length                       0.07
#  307                         park | bus                          0.07
#  308                       gained | gain                         0.07
#  309                         road | spread                       0.07
#  310                      contact | transfer                     0.07
#  311                        event | table                        0.06
#  312                         user | savings                      0.06
#  313                      weekend | week                         0.06
#  314                      concept | card                         0.06
#  315                        claim | bigger                       0.06
#  316                     daughter | son                          0.06
#  317                  operational | operator                     0.06
#  318                     continue | continuing                   0.06
#  319                         unit | room                         0.06
#  320                     students | million                      0.06
#  321                       living | live                         0.06
#  322                    establish | chairman                     0.06
#  323                         debt | negative                     0.06
#  324                        storm | peak                         0.06
#  325                     reaction | involve                      0.06
#  326                       starts | start                        0.06
#  327                     targeted | stolen                       0.06
#  328                    professor | teacher                      0.06
#  329                       thrown | placed                       0.06
#  330                         self | internal                     0.06
#  331                     rejected | recognized                   0.06
#  332                     wireless | half                         0.06
#  333                      respond | injured                      0.06
#  334                  represented | represent                    0.06
#  335                       myself | ourselves                    0.06
#  336                     forecast | loss                         0.06
#  337                   facilities | property                     0.06
#  338                      greater | more                         0.06
#  339                    indicated | represented                  0.06
#  340                     policies | topic                        0.06
#  341                         boss | co                           0.06
#  342                       leader | not                          0.06
#  343                    awareness | identity                     0.06
#  344                      initial | second                       0.06
#  345                      feeling | secure                       0.06
#  346                       writer | writing                      0.06
#  347                         plan | step                         0.06
#  348                        dream | sleep                        0.06
#  349                     strongly | highly                       0.06
#  350                      deliver | halftime                     0.06
#  351                   healthcare | funds                        0.06
#  352                       factor | involved                     0.06
#  353                        clear | net                          0.06
#  354                 contribution | contribute                   0.06
#  355                         ends | ended                        0.06
#  356                consideration | practice                     0.05
#  357                       choose | junior                       0.05
#  358                      located | maintenance                  0.05
#  359                         mark | behavior                     0.05
#  360                         heat | photos                       0.05
#  361                          hot | first                        0.05
#  362                       nation | properly                     0.05
#  363                     changing | change                       0.05
#  364                     attorney | president                    0.05
#  365                        visit | pop                          0.05
#  366                        lives | life                         0.05
#  367                      popular | rally                        0.05
#  368                          bag | good                         0.05
#  369                     informed | immediately                  0.05
#  370                    treatment | treat                        0.05
#  371                         hand | hands                        0.05
#  372                       grants | granted                      0.05
#  373                       option | options                      0.05
#  374                        adult | adults                       0.05
#  375                      edition | including                    0.05
#  376                       ticket | tickets                      0.05
#  377                            s | crore                        0.05
#  378                      numbers | number                       0.05
#  379                       repair | insurance                    0.05
#  380                        level | levels                       0.05
#  381                       reform | care                         0.05
#  382                    effective | anti                         0.05
#  383                        happy | excited                      0.05
#  384                  responsible | assist                       0.05
#  385                participation | representatives              0.05
#  386                      through | way                          0.05
#  387                       remove | fix                          0.05
#  388                         gets | got                          0.05
#  389                       earned | least                        0.05
#  390                        proud | tax                          0.05
#  391                       decide | decided                      0.05
#  392                      storage | parking                      0.05
#  393                       office | window                       0.05
#  394                       single | individual                   0.05
#  395                          art | audience                     0.05
#  396                      sharing | shared                       0.05
#  397                        eight | six                          0.05
#  398                       matter | fact                         0.05
#  399                     favorite | popular                      0.05
#  400                       highly | extremely                    0.05
#  401                      follows | then                         0.05
#  402                      profits | profit                       0.05
#  403                        place | places                       0.05
#  404                        start | starting                     0.05
#  405                     election | elections                    0.05
#  406                       enough | too                          0.04
#  407                       making | makes                        0.04
#  408                    requested | required                     0.04
#  409                       seemed | seem                         0.04
#  410                   particular | exactly                      0.04
#  411                  real_estate | real                         0.04
#  412                        album | seventh                      0.04
#  413                        image | images                       0.04
#  414                       square | young                        0.04
#  415                        state | driving                      0.04
#  416                     exchange | switch                       0.04
#  417                        based | need                         0.04
#  418                          out | nearly                       0.04
#  419                         acts | act                          0.04
#  420                          boy | guy                          0.04
#  421                    terrorist | political                    0.04
#  422                     minister | reporters                    0.04
#  423                      officer | pilot                        0.04
#  424                          pre | typical                      0.04
#  425                        squad | gathered                     0.04
#  426                        keeps | keep                         0.04
#  427                      leading | filled                       0.04
#  428                        entry | having                       0.04
#  429                       letter | mail                         0.04
#  430                    providing | provide                      0.04
#  431                        comes | came                         0.04
#  432                     defeated | returned                     0.04
#  433                   individual | inning                       0.04
#  434                     accepted | accept                       0.04
#  435                       ranked | ranking                      0.04
#  436                       memory | gas                          0.04
#  437                     coverage | career                       0.04
#  438                    statement | e_mail                       0.04
#  439                      morning | afternoon                    0.04
#  440                       resume | decrease                     0.04
#  441                         live | lived                        0.04
#  442                       killed | wounded                      0.04
#  443                       signal | operation                    0.04
#  444                      invited | qualified                    0.04
#  445                      advance | move                         0.03
#  446                          top | break                        0.03
#  447                        trend | shift                        0.03
#  448                     approved | approval                     0.03
#  449                        begin | begun                        0.03
#  450                          hit | well                         0.03
#  451                       accept | lower                        0.03
#  452                        never | ever                         0.03
#  453                     resident | competitors                  0.03
#  454                         wave | blow                         0.03
#  455                      climate | climate_change               0.03
#  456                          new | newly                        0.03
#  457                         feel | sense                        0.03
#  458                        third | fifth                        0.03
#  459                    immediate | settled                      0.03
#  460                         give | gave                         0.03
#  461                      neither | nor                          0.03
#  462                  communities | community                    0.03
#  463                    following | follow                       0.03
#  464                         team | national                     0.03
#  465                         move | moved                        0.03
#  466                     response | return                       0.03
#  467                      smaller | small                        0.03
#  468                           no | nothing                      0.03
#  469                    estimated | projected                    0.03
#  470                      century | decade                       0.03
#  471                         cost | priority                     0.03
#  472                      account | deep                         0.03
#  473                        cross | cents                        0.03
#  474                       rather | selection                    0.03
#  475                      failure | failed                       0.03
#  476                        debut | rookie                       0.03
#  477                         page | brain                        0.03
#  478                       return | back                         0.03
#  479                     property | bar                          0.03
#  480                          fun | healthy                      0.03
#  481                       placed | place                        0.03
#  482                         part | certainly                    0.03
#  483                          use | interest                     0.03
#  484                        press | press_release                0.03
#  485                      replace | replacement                  0.03
#  486                       rating | ratings                      0.03
#  487                       survey | poll                         0.03
#  488                     decrease | reduction                    0.03
#  489                        dozen | several                      0.03
#  490                 presentation | connection                   0.03
#  491                      illegal | steel                        0.03
#  492                        floor | stage                        0.03
#  493                         done | do                           0.02
#  494                       denied | neither                      0.02
#  495                       credit | critics                      0.02
#  496                  appropriate | older                        0.02
#  497                         earn | an                           0.02
#  498                      eastern | southern                     0.02
#  499                   innovation | addition                     0.02

# %% [markdown]
# ### Step 4: Analyzing gender bias in word vectors asscoiated with professions
#
# Next, we show that many occupations are unintendedly associated with either male of female by projecting their word vectors onto the gender dimension.
#
# The script will output the profession words sorted with respect to the projection score in the direction of gender.

# %%
# profession analysis gender
sp = sorted([(E.v(w).dot(v_gender), w) for w in profession_words])

sp[0:20], sp[-20:]
# Out:
# ([(-0.15426257, 'colonel'),
#   (-0.15058891, 'councilor'),
#   (-0.14500904, 'trooper'),
#   (-0.14300711, 'physicist'),
#   (-0.14258763, 'mediator'),
#   (-0.14220968, 'cop'),
#   (-0.14110851, 'surveyor'),
#   (-0.14024815, 'undersecretary'),
#   (-0.14019847, 'valedictorian'),
#   (-0.13929208, 'maestro'),
#   (-0.13917962, 'politician'),
#   (-0.13780122, 'congressman'),
#   (-0.13667953, 'narrator'),
#   (-0.13652092, 'librarian'),
#   (-0.1363942, 'vice_chancellor'),
#   (-0.13622355, 'commander'),
#   (-0.13523717, 'historian'),
#   (-0.13507493, 'pharmacist'),
#   (-0.13445523, 'administrator'),
#   (-0.13370223, 'statesman')],
#  [(-0.049532346, 'janitor'),
#   (-0.049290616, 'bodyguard'),
#   (-0.04897745, 'illustrator'),
#   (-0.048656467, 'clerk'),
#   (-0.047931194, 'fisherman'),
#   (-0.046674065, 'secretary'),
#   (-0.045202546, 'athletic_director'),
#   (-0.041083053, 'evangelist'),
#   (-0.040735602, 'correspondent'),
#   (-0.039575815, 'solicitor_general'),
#   (-0.039214253, 'financier'),
#   (-0.03868881, 'preacher'),
#   (-0.033756364, 'aide'),
#   (-0.033012364, 'accountant'),
#   (-0.029756054, 'gangster'),
#   (-0.020630635, 'researcher'),
#   (-0.02046905, 'ballplayer'),
#   (-0.019559726, 'broadcaster'),
#   (0.017871648, 'plumber'),
#   (0.02158992, 'philanthropist')])

# %% [markdown]
# ## Part 2 Racial Bias
#
# ### Step 5: Define racial direction
# We define racial direction based on the common names in different Demographic groups.

# %%
names = ["Emily", "Aisha", "Anne", "Keisha", "Jill", "Tamika", "Allison", "Lakisha", "Laurie", "Tanisha", "Sarah",
         "Latoya", "Meredith", "Kenya", "Carrie", "Latonya", "Kristen", "Ebony", "Todd", "Rasheed", "Neil", "Tremayne",
         "Geoffrey", "Kareem", "Brett", "Darnell", "Brendan", "Tyrone", "Greg", "Hakim", "Matthew", "Jamal", "Jay",
         "Leroy", "Brad", "Jermaine"]
names_group1 = [names[2 * i] for i in range(len(names) // 2)]
names_group2 = [names[2 * i + 1] for i in range(len(names) // 2)]

# %%
# racial direction
vs = [sum(E.v(w) for w in names) for names in (names_group2, names_group1)]
vs = [v / np.linalg.norm(v) for v in vs]

v_racial = vs[1] - vs[0]
v_racial = v_racial / np.linalg.norm(v_racial)

# %% [markdown]
# ### Step 6: Generating racial biased analogies
#
# Similar to Step 3, we generate analogies that align with the racial dimension.

# %%
# racial analogies
a_racial = E.best_analogies_dist_thresh(v_racial, max_words=1000)

# for (a,b,c) in a_racial:
#     print(a+"-"+b)
we.viz(a_racial)
# Out:
#    0                      players | talk                         0.29
#    1                    announced | used                         0.29
#    2                       ensure | very                         0.29
#    3                     continue | offering                     0.27
#    4                      details | access                       0.27
#    5                   everything | only                         0.26
#    6                        goals | use                          0.26
#    7                     earnings | book                         0.25
#    8                     provided | way                          0.25
#    9                       scored | any                          0.24
#   10                       within | order                        0.24
#   11                      markets | built                        0.24
#   12                      scoring | network                      0.24
#   13                         news | lot                          0.24
#   14                         save | calls                        0.23
#   15                       player | vehicle                      0.23
#   16                      reached | shows                        0.23
#   17                       become | body                         0.23
#   18                        force | by                           0.23
#   19                        cases | special                      0.23
#   20                     attorney | times                        0.23
#   21                       others | number                       0.23
#   22                        those | given                        0.23
#   23                     football | water                        0.23
#   24                     reported | long                         0.22
#   25                      contact | made                         0.22
#   26                    following | club                         0.22
#   27                       follow | ever                         0.22
#   28                           pm | time                         0.22
#   29                         feel | straight                     0.21
#   30                   television | call                         0.21
#   31                    continues | group                        0.21
#   32                        cents | both                         0.21
#   33                         jobs | drug                         0.21
#   34                       agency | worth                        0.21
#   35                        along | party                        0.21
#   36                        track | district                     0.21
#   37                      reports | either                       0.21
#   38                        below | level                        0.21
#   39                    something | things                       0.21
#   40                      certain | rights                       0.21
#   41                          its | show                         0.20
#   42                    continued | low                          0.20
#   43                      efforts | trip                         0.20
#   44                       remain | how                          0.20
#   45                         read | cut                          0.20
#   46                         felt | because                      0.19
#   47                        staff | senior                       0.19
#   48                       social | traffic                      0.19
#   49                     families | county                       0.19
#   50                       enough | different                    0.19
#   51                         fell | raised                       0.19
#   52                         play | role                         0.19
#   53                      comment | making                       0.19
#   54                    thousands | event                        0.19
#   55                         sure | make                         0.19
#   56                      against | through                      0.19
#   57                        media | national                     0.19
#   58                   conference | plant                        0.18
#   59                      someone | month                        0.18
#   60                       expect | stock                        0.18
#   61                        ahead | up                           0.18
#   62                         such | high                         0.18
#   63                     concerns | want                         0.18
#   64                     election | fact                         0.18
#   65                       became | systems                      0.18
#   66                         find | has                          0.18
#   67                        spent | beat                         0.18
#   68                        rates | annual                       0.17
#   69                       recent | ago                          0.17
#   70                      decided | round                        0.17
#   71                         fund | real                         0.17
#   72                       finish | top                          0.17
#   73                    completed | do                           0.17
#   74                          her | addition                     0.17
#   75                         keep | am                           0.17
#   76                         post | commercial                   0.17
#   77                      provide | system                       0.17
#   78                    education | treatment                    0.17
#   79                      ability | contract                     0.17
#   80                   throughout | all                          0.17
#   81                      improve | reduce                       0.17
#   82                      charged | non                          0.17
#   83                       signed | done                         0.17
#   84                     pressure | especially                   0.16
#   85                        wrote | we                           0.16
#   86                     released | bit                          0.16
#   87                        named | regular                      0.16
#   88                      created | opportunity                  0.16
#   89                        costs | response                     0.16
#   90                        small | makes                        0.16
#   91                    statement | million                      0.16
#   92                      working | looking                      0.16
#   93                      website | home                         0.16
#   94                        large | old                          0.16
#   95                        final | ended                        0.16
#   96                       should | gets                         0.16
#   97                       dollar | nation                       0.16
#   98                     shooting | giving                       0.16
#   99                    residents | content                      0.16
#  100                         away | right                        0.16
#  101                          oil | part                         0.16
#  102                     received | go                           0.16
#  103                    committee | according                    0.16
#  104                   tournament | night                        0.16
#  105                   statements | challenge                    0.16
#  106                        would | using                        0.15
#  107                    employees | production                   0.15
#  108                     director | town                         0.15
#  109                         goal | much                         0.15
#  110                        hours | days                         0.15
#  111                      outside | leader                       0.15
#  112                     campaign | sales                        0.15
#  113                         must | had                          0.15
#  114                        areas | city                         0.15
#  115                       across | levels                       0.15
#  116                      manager | situation                    0.15
#  117                         took | taking                       0.15
#  118                       behind | never                        0.15
#  119                       forces | being                        0.15
#  120                      attacks | since                        0.15
#  121                         four | two                          0.14
#  122                          yet | also                         0.14
#  123                        later | earlier                      0.14
#  124                       driver | deal                         0.14
#  125                     children | land                         0.14
#  126                        chief | leading                      0.14
#  127                         into | can                          0.14
#  128                       worked | wanted                       0.14
#  129                       fourth | third                        0.14
#  130                        death | age                          0.14
#  131                       attack | interview                    0.14
#  132                       policy | term                         0.14
#  133                      whether | having                       0.14
#  134                         next | every                        0.14
#  135                     approved | wants                        0.14
#  136                      forward | before                       0.14
#  137                         line | law                          0.14
#  138                         fuel | energy                       0.14
#  139                   themselves | give                         0.14
#  140                         stay | good                         0.14
#  141                          win | cash                         0.14
#  142                    important | about                        0.14
#  143                    consumers | man                          0.14
#  144                          few | compared                     0.14
#  145                     everyone | anything                     0.14
#  146                         spot | based                        0.13
#  147                         here | now                          0.13
#  148                     spending | government                   0.13
#  149                    insurance | returned                     0.13
#  150                     military | federal                      0.13
#  151                     included | lower                        0.13
#  152                     complete | again                        0.13
#  153                         hope | offered                      0.13
#  154                      current | interest                     0.13
#  155                         runs | sense                        0.13
#  156                         hits | hit                          0.13
#  157                       season | year                         0.13
#  158                         hour | weeks                        0.13
#  159                    political | road                         0.13
#  160                        range | video                        0.13
#  161                     comments | whole                        0.13
#  162                         goes | went                         0.13
#  163                          his | have                         0.13
#  164                        homes | stage                        0.12
#  165                         risk | serious                      0.12
#  166                      leaders | former                       0.12
#  167                        tried | could                        0.12
#  168                       impact | end                          0.12
#  169                     proposed | place                        0.12
#  170                       winner | once                         0.12
#  171                      parents | capital                      0.12
#  172                      allowed | limited                      0.12
#  173                       create | does                         0.12
#  174                         fall | rest                         0.11
#  175                      defense | fight                        0.11
#  176                         died | helped                       0.11
#  177                         what | you                          0.11
#  178                       strong | early                        0.11
#  179                      friends | trial                        0.11
#  180                         wife | woman                        0.11
#  181                        score | amount                       0.11
#  182                         loss | half                         0.11
#  183                         less | no                           0.11
#  184                         fans | get                          0.11
#  185                        plays | is                           0.11
#  186                investigation | budget                       0.11
#  187                        going | really                       0.11
#  188                    advantage | mobile                       0.11
#  189                       adding | officials                    0.11
#  190                           if | base                         0.11
#  191                         guys | did                          0.11
#  192                        hopes | chance                       0.11
#  193                      overall | actually                     0.11
#  194                         last | coming                       0.11
#  195                        front | back                         0.11
#  196                  environment | source                       0.11
#  197                     increase | increased                    0.11
#  198                   experience | offer                        0.11
#  199                     expected | ground                       0.11
#  200                        seven | team                         0.11
#  201                       effort | period                       0.11
#  202                      running | local                        0.10
#  203                        price | quality                      0.10
#  204                     research | problems                     0.10
#  205                   successful | beginning                    0.10
#  206                      despite | doing                        0.10
#  207                     required | involved                     0.10
#  208                        trade | job                          0.10
#  209                      driving | movie                        0.10
#  210                      similar | common                       0.10
#  211                        filed | hearing                      0.10
#  212                        light | young                        0.10
#  213                      officer | account                      0.10
#  214                           in | black                        0.10
#  215                    difficult | service                      0.10
#  216                      believe | basis                        0.10
#  217                   department | billion                      0.10
#  218                      average | highest                      0.10
#  219                       looked | look                         0.10
#  220                    companies | list                         0.10
#  221                         firm | ways                         0.10
#  222                     question | sell                         0.10
#  223                     consumer | getting                      0.10
#  224                         this | weekend                      0.09
#  225                       people | happy                        0.09
#  226                      general | bank                         0.09
#  227                        words | phone                        0.09
#  228                       crisis | debt                         0.09
#  229                        allow | offers                       0.09
#  230                       during | around                       0.09
#  231                         near | be                           0.09
#  232                    investors | authorities                  0.09
#  233                organizations | organization                 0.09
#  234                        where | first                        0.09
#  235                        moved | decision                     0.09
#  236                       agreed | agreement                    0.09
#  237                       global | better                       0.09
#  238                       living | live                         0.09
#  239                       moving | even                         0.09
#  240                        still | example                      0.09
#  241                  significant | many                         0.09
#  242                         meet | with                         0.09
#  243                        needs | need                         0.09
#  244                        works | bad                          0.09
#  245                       center | late                         0.09
#  246                      playing | same                         0.09
#  247                       though | view                         0.08
#  248                    providing | services                     0.08
#  249                         hold | pretty                       0.08
#  250                        these | side                         0.08
#  251                    questions | president                    0.08
#  252                      biggest | big                          0.08
#  253                       mother | due                          0.08
#  254                        clear | open                         0.08
#  255                        after | led                          0.08
#  256                      instead | summer                       0.08
#  257                       single | set                          0.08
#  258                        rules | plan                         0.08
#  259                         kept | world                        0.08
#  260                     evidence | total                        0.08
#  261                        their | construction                 0.08
#  262                         John | business                     0.08
#  263                      address | search                       0.08
#  264                        might | without                      0.08
#  265                      success | review                       0.08
#  266                       fiscal | quarter                      0.08
#  267                        lives | date                         0.08
#  268                          she | he                           0.08
#  269                         five | three                        0.08
#  270                       issues | hand                         0.08
#  271                          met | seen                         0.07
#  272                    potential | least                        0.07
#  273                     appeared | workers                      0.07
#  274                       action | well                         0.07
#  275                      various | administration               0.07
#  276                       longer | short                        0.07
#  277                      economy | week                         0.07
#  278                        serve | gas                          0.07
#  279                        teams | own                          0.07
#  280                         more | often                        0.07
#  281                      project | star                         0.07
#  282                     provides | member                       0.07
#  283                        seems | years                        0.07
#  284                          son | child                        0.07
#  285                        added | troops                       0.07
#  286                        match | court                        0.07
#  287                      results | there                        0.07
#  288                       growth | profit                       0.07
#  289                         cost | paid                         0.07
#  290                   conditions | past                         0.07
#  291                       person | kind                         0.07
#  292                      accused | class                        0.07
#  293                      support | public                       0.07
#  294                         pick | competition                  0.07
#  295                         them | the                          0.07
#  296                    community | performance                  0.07
#  297                    executive | investment                   0.07
#  298                        yards | idea                         0.07
#  299                        legal | reason                       0.07
#  300                        tough | ready                        0.07
#  301                       online | white                        0.06
#  302                      brought | money                        0.06
#  303                         then | per                          0.06
#  304                        reach | got                          0.06
#  305                        asked | ask                          0.06
#  306                       forced | down                         0.06
#  307                    customers | attention                    0.06
#  308                        bring | was                          0.06
#  309                         site | property                     0.06
#  310                        stand | see                          0.06
#  311                      remains | building                     0.06
#  312                       course | help                         0.06
#  313                          but | who                          0.06
#  314                       killed | new                          0.06
#  315                           my | your                         0.06
#  316                         gone | break                        0.06
#  317                       happen | when                         0.06
#  318                         vote | than                         0.06
#  319                        found | build                        0.06
#  320                        whose | which                        0.06
#  321                      schools | school                       0.06
#  322                     happened | story                        0.06
#  323                    financial | why                          0.05
#  324                          war | space                        0.05
#  325                     industry | per_cent                     0.05
#  326                      himself | some                         0.05
#  327                        field | me                           0.05
#  328                       states | present                      0.05
#  329                        cause | been                         0.05
#  330                       shares | not                          0.05
#  331                      private | study                        0.05
#  332                     practice | training                     0.05
#  333                      largest | always                       0.05
#  334                       likely | almost                       0.05
#  335                         sign | form                         0.05
#  336                        fifth | including                    0.05
#  337                       toward | closed                       0.05
#  338                          net | left                         0.05
#  339                       market | sold                         0.05
#  340                       passed | equipment                    0.05
#  341                          run | or                           0.05
#  342                     economic | numbers                      0.05
#  343                        share | revenue                      0.05
#  344                          out | college                      0.05
#  345                           an | taken                        0.05
#  346                      however | focus                        0.05
#  347                     hospital | process                      0.05
#  348                        began | start                        0.05
#  349                   understand | needed                       0.05
#  350                      further | on                           0.05
#  351                          may | other                        0.05
#  352                        think | sent                         0.05
#  353                        issue | board                        0.04
#  354                         pass | rather                       0.04
#  355                         mean | showed                       0.04
#  356                      morning | afternoon                    0.04
#  357                          six | said                         0.04
#  358                         know | knew                         0.04
#  359                          try | together                     0.04
#  360                     products | product                      0.04
#  361                        today | day                          0.04
#  362                       second | information                  0.04
#  363                       charge | members                      0.04
#  364                  development | features                     0.04
#  365                       design | work                         0.04
#  366                       change | changes                      0.04
#  367                     personal | close                        0.04
#  368                  immediately | quickly                      0.04
#  369                         care | fire                         0.04
#  370                         ball | career                       0.04
#  371                       posted | opened                       0.04
#  372                      receive | head                         0.04
#  373                        drive | data                         0.04
#  374                       police | cars                         0.04
#  375                      nothing | starting                     0.04
#  376                         area | claims                       0.04
#  377                       safety | security                     0.04
#  378                         rise | pay                          0.04
#  379                         soon | too                          0.04
#  380                       series | house                        0.03
#  381                        takes | take                         0.03
#  382                         free | heart                        0.03
#  383                    scheduled | position                     0.03
#  384                       turned | nearly                       0.03
#  385                          air | life                         0.03
#  386                          say | particularly                 0.03
#  387                    yesterday | problem                      0.03
#  388                         dead | finished                     0.03
#  389                          off | point                        0.03
#  390                        quite | full                         0.03
#  391                     although | points                       0.03
#  392                    marketing | let                          0.03
#  393                        major | main                         0.03
#  394                         came | tell                         0.03
#  395                         rate | state                        0.03
#  396                      another | one                          0.03
#  397                    operating | positive                     0.03
#  398                       issued | that                         0.03
#  399                       inside | buy                          0.03
#  400                          men | include                      0.03
#  401                          won | winning                      0.03
#  402                        raise | country                      0.03
#  403                         held | terms                        0.03
#  404                       little | minutes                      0.03
#  405                      release | foot                         0.03
#  406                       failed | minute                       0.03
#  407                        great | huge                         0.03
#  408                      planned | considered                   0.02
#  409                        comes | trying                       0.02
#  410                         race | league                       0.02
#  411                         they | simply                       0.02
#  412                       itself | face                         0.02
#  413                          far | entire                       0.02
#  414                   businesses | programs                     0.02
#  415                         turn | host                         0.02
#  416                        eight | double                       0.02
#  417                        while | benefit                      0.02
#  418                         step | shot                         0.02
#  419                     software | store                        0.02
#  420                     arrested | council                      0.02
#  421                     followed | told                         0.02
#  422                        games | car                          0.02
#  423                        means | already                      0.02
#  424                international | travel                       0.02
#  425                        talks | designed                     0.02
#  426                          put | above                        0.02
#  427                       months | program                      0.02
#  428                    countries | officers                     0.02
#  429                        miles | our                          0.02
#  430                       income | unit                         0.02
#  431                        power | opening                      0.02
#  432                   activities | heard                        0.02
#  433                        among | several                      0.02
#  434                       office | visit                        0.02
#  435                          him | banks                        0.02
#  436                       served | anyone                       0.02
#  437                   additional | solutions                    0.02
#  438                      dropped | case                         0.02
#  439                        funds | owner                        0.01
#  440                         feet | record                       0.01
#  441                        thing | violence                     0.01
#  442                         nine | game                         0.01
#  443                       demand | control                      0.01
#  444                    spokesman | rose                         0.01
#  445                        known | love                         0.01
#  446                     students | sale                         0.01
#  447                       played | hard                         0.01
#  448                       prices | credit                       0.01
#  449                   management | kids                         0.01
#  450                      student | able                         0.01
#  451                        users | value                        0.01
#  452                       father | matter                       0.01
#  453                         test | were                         0.01
#  454                        under | plans                        0.01
#  455                         most | will                         0.01
#  456                      funding | medical                      0.01
#  457                     official | easy                         0.01
#  458                       groups | started                      0.01
#  459                       called | move                         0.01
#  460                       future | region                       0.01
#  461                         lost | hands                        0.01
#  462                         come | title                        0.01
#  463                       result | best                         0.01
#  464                      trading | women                        0.01
#  465                      related | so                           0.01
#  466                     projects | available                    0.01
#  467                           us | from                         0.00
#  468                           it | charges                      0.00
#  469                          saw | film                         0.00
#  470                      popular | stop                         0.00
#  471                    currently | just                         0.00
#  472                         food | history                      0.00
#  473                     benefits | planning                     0.00
#  474                       family | couple                       0.00
#  475                       report | for                          0.00
#  476                      meeting | between                      0.00
#  477                        judge | growing                      0.00
#  478                         like | leave                        0.00
#  479                       prison | are                          0.00
#  480                      victory | health                       0.00
#  481                 applications | begin                        0.00
#  482                        music | thought                      0.00
#  483                       return | sector                       0.00
#  484                         bill | each                         0.00
#  485                     includes | possible                     0.00
#  486                        until | technology                   0.00
#  487                      dollars | percent                      0.00
#  488                     patients | name                         0.00
#  489                         gave | company                      0.00
#  490                      foreign | probably                     0.00
#  491                     chairman | coach                        0.00
#  492                          key | assets                       0.00
#  493                       higher | as                           0.00
#  494                           at | lead                         0.00
#  495                       saying | says                         0.00

# %% [markdown]
# ### Step 7: Analyzing racial bias in word vectors asscoiated with professions
#
# Similar to Step 4, we project occpurations onto the racial dimension.

# %%
# profession analysis racial
sp = sorted([(E.v(w).dot(v_racial), w) for w in profession_words])

sp[0:20], sp[-20:]
# Out:
# ([(-0.07526696, 'stockbroker'),
#   (-0.072013855, 'shopkeeper'),
#   (-0.06997903, 'publicist'),
#   (-0.06425414, 'welder'),
#   (-0.06420424, 'realtor'),
#   (-0.06265733, 'epidemiologist'),
#   (-0.061484993, 'bookkeeper'),
#   (-0.059125546, 'housewife'),
#   (-0.05522476, 'socialite'),
#   (-0.049128495, 'baker'),
#   (-0.048213784, 'cabbie'),
#   (-0.04816783, 'organist'),
#   (-0.04775571, 'drug_addict'),
#   (-0.047214143, 'dermatologist'),
#   (-0.045817573, 'sportswriter'),
#   (-0.04415521, 'investment_banker'),
#   (-0.04396136, 'environmentalist'),
#   (-0.04165364, 'barber'),
#   (-0.0414836, 'guidance_counselor'),
#   (-0.041086137, 'pundit')],
#  [(0.07394397, 'pianist'),
#   (0.0743814, 'programmer'),
#   (0.074969664, 'pathologist'),
#   (0.07520779, 'correspondent'),
#   (0.075593255, 'waiter'),
#   (0.07573603, 'inventor'),
#   (0.0758131, 'secretary'),
#   (0.07964485, 'nun'),
#   (0.08239908, 'pediatrician'),
#   (0.087414026, 'chemist'),
#   (0.0879491, 'footballer'),
#   (0.095166184, 'inspector'),
#   (0.10305147, 'commentator'),
#   (0.10351421, 'mathematician'),
#   (0.104534075, 'physician'),
#   (0.107358254, 'bodyguard'),
#   (0.10979076, 'treasurer'),
#   (0.10981712, 'diplomat'),
#   (0.12294882, 'journalist'),
#   (0.12471017, 'researcher')])

# %% [markdown]
# ## Exercise
#
# Repeat Step 2-4 with debiased word embedding.
#
# You can use debiaswe debias function to do the debiasing with word sets of your choosing
#
# You can leave equalize_pairs and gender_specific_words blank when coming up with your own groups. We give an example for the case of gender below for you to warm up.

# %%
from debiaswe.debias import debias

# %%
# Lets load some gender related word lists to help us with debiasing
with open('./data/definitional_pairs.json', "r") as f:
    defs = json.load(f)
print("definitional", defs)

with open('./data/equalize_pairs.json', "r") as f:
    equalize_pairs = json.load(f)

with open('./data/gender_specific_seed.json', "r") as f:
    gender_specific_words = json.load(f)
print("gender specific", len(gender_specific_words), gender_specific_words[:10])
# Out:
# definitional [['woman', 'man'], ['girl', 'boy'], ['she', 'he'], ['mother', 'father'], ['daughter', 'son'], ['gal', 'guy'], ['female', 'male'], ['her', 'his'], ['herself', 'himself'], ['Mary', 'John']]
# gender specific 218 ['actress', 'actresses', 'aunt', 'aunts', 'bachelor', 'ballerina', 'barbershop', 'baritone', 'beard', 'beards']

# %%
debias(E, gender_specific_words, defs, equalize_pairs)
# Out:
# 26423 words of dimension 768 : in, for, that, is, ..., Jay, Leroy, Brad, Jermaine
# {('SPOKESMAN', 'SPOKESWOMAN'), ('PROSTATE_CANCER', 'OVARIAN_CANCER'), ('MALE', 'FEMALE'), ('BOY', 'GIRL'), ('GRANDSONS', 'GRANDDAUGHTERS'), ('boy', 'girl'), ('male', 'female'), ('fathers', 'mothers'), ('CATHOLIC_PRIEST', 'NUN'), ('Dad', 'Mom'), ('MEN', 'WOMEN'), ('Gentleman', 'Lady'), ('dudes', 'gals'), ('Nephew', 'Niece'), ('father', 'mother'), ('DUDES', 'GALS'), ('BROTHERS', 'SISTERS'), ('GELDING', 'MARE'), ('Males', 'Females'), ('dad', 'mom'), ('grandpa', 'grandma'), ('BROTHER', 'SISTER'), ('prostate_cancer', 'ovarian_cancer'), ('fatherhood', 'motherhood'), ('HE', 'SHE'), ('son', 'daughter'), ('businessman', 'businesswoman'), ('wives', 'husbands'), ('SONS', 'DAUGHTERS'), ('Chairman', 'Chairwoman'), ('He', 'She'), ('CONGRESSMAN', 'CONGRESSWOMAN'), ('males', 'females'), ('nephew', 'niece'), ('brothers', 'sisters'), ('Uncle', 'Aunt'), ('Boys', 'Girls'), ('grandfather', 'grandmother'), ('Schoolboy', 'Schoolgirl'), ('himself', 'herself'), ('HIMSELF', 'HERSELF'), ('Fatherhood', 'Motherhood'), ('councilman', 'councilwoman'), ('COUNCILMAN', 'COUNCILWOMAN'), ('FELLA', 'GRANNY'), ('Boy', 'Girl'), ('Monastery', 'Convent'), ('Colt', 'Filly'), ('COLT', 'FILLY'), ('Fella', 'Granny'), ('KINGS', 'QUEENS'), ('SON', 'DAUGHTER'), ('Wives', 'Husbands'), ('FRATERNITY', 'SORORITY'), ('gelding', 'mare'), ('Prince', 'Princess'), ('MAN', 'WOMAN'), ('His', 'Her'), ('Grandsons', 'Granddaughters'), ('Brother', 'Sister'), ('congressman', 'congresswoman'), ('fella', 'granny'), ('King', 'Queen'), ('EX_GIRLFRIEND', 'EX_BOYFRIEND'), ('grandson', 'granddaughter'), ('NEPHEW', 'NIECE'), ('GENTLEMAN', 'LADY'), ('PRINCE', 'PRINCESS'), ('monastery', 'convent'), ('prince', 'princess'), ('Fraternity', 'Sorority'), ('Fathers', 'Mothers'), ('Men', 'Women'), ('Kings', 'Queens'), ('CHAIRMAN', 'CHAIRWOMAN'), ('Son', 'Daughter'), ('FATHER', 'MOTHER'), ('Twin_Brother', 'Twin_Sister'), ('boys', 'girls'), ('Gentlemen', 'Ladies'), ('Prostate_Cancer', 'Ovarian_Cancer'), ('testosterone', 'estrogen'), ('his', 'her'), ('Gelding', 'Mare'), ('gentlemen', 'ladies'), ('grandsons', 'granddaughters'), ('colt', 'filly'), ('ex_girlfriend', 'ex_boyfriend'), ('Spokesman', 'Spokeswoman'), ('sons', 'daughters'), ('catholic_priest', 'nun'), ('TWIN_BROTHER', 'TWIN_SISTER'), ('Father', 'Mother'), ('he', 'she'), ('Grandson', 'Granddaughter'), ('SCHOOLBOY', 'SCHOOLGIRL'), ('Testosterone', 'Estrogen'), ('DAD', 'MOM'), ('GRANDFATHER', 'GRANDMOTHER'), ('UNCLE', 'AUNT'), ('HIS', 'HER'), ('Male', 'Female'), ('Sons', 'Daughters'), ('men', 'women'), ('gentleman', 'lady'), ('BOYS', 'GIRLS'), ('GRANDSON', 'GRANDDAUGHTER'), ('Himself', 'Herself'), ('KING', 'QUEEN'), ('dads', 'moms'), ('WIVES', 'HUSBANDS'), ('Congressman', 'Congresswoman'), ('Councilman', 'Councilwoman'), ('spokesman', 'spokeswoman'), ('Ex_Girlfriend', 'Ex_Boyfriend'), ('FATHERS', 'MOTHERS'), ('BUSINESSMAN', 'BUSINESSWOMAN'), ('Grandfather', 'Grandmother'), ('fraternity', 'sorority'), ('schoolboy', 'schoolgirl'), ('Man', 'Woman'), ('Businessman', 'Businesswoman'), ('chairman', 'chairwoman'), ('twin_brother', 'twin_sister'), ('DADS', 'MOMS'), ('man', 'woman'), ('Dudes', 'Gals'), ('MONASTERY', 'CONVENT'), ('kings', 'queens'), ('Catholic_Priest', 'Nun'), ('king', 'queen'), ('Grandpa', 'Grandma'), ('brother', 'sister'), ('uncle', 'aunt'), ('Brothers', 'Sisters'), ('GRANDPA', 'GRANDMA'), ('Dads', 'Moms'), ('FATHERHOOD', 'MOTHERHOOD'), ('MALES', 'FEMALES'), ('GENTLEMEN', 'LADIES'), ('TESTOSTERONE', 'ESTROGEN')}
# 26423 words of dimension 768 : in, for, that, is, ..., Jay, Leroy, Brad, Jermaine

# %%
# profession analysis gender
sp_debiased = sorted([(E.v(w).dot(v_gender), w) for w in profession_words])

sp_debiased[0:20], sp_debiased[-20:]
# Out:
# ([(-0.16929759, 'councilor'),
#   (-0.16828442, 'congressman'),
#   (-0.16664192, 'colonel'),
#   (-0.162978, 'mediator'),
#   (-0.16251725, 'undersecretary'),
#   (-0.16219766, 'trooper'),
#   (-0.16036008, 'narrator'),
#   (-0.15956642, 'politician'),
#   (-0.15902817, 'physicist'),
#   (-0.15899193, 'valedictorian'),
#   (-0.157693, 'librarian'),
#   (-0.15766348, 'administrator'),
#   (-0.15666589, 'cop'),
#   (-0.15642822, 'maestro'),
#   (-0.15593147, 'commander'),
#   (-0.15578131, 'surveyor'),
#   (-0.15548019, 'vice_chancellor'),
#   (-0.15481347, 'teenager'),
#   (-0.15455693, 'neurosurgeon'),
#   (-0.15375139, 'ambassador')],
#  [(-0.06659895, 'clerk'),
#   (-0.06503406, 'boxer'),
#   (-0.06446973, 'tycoon'),
#   (-0.062462583, 'athletic_director'),
#   (-0.061547413, 'evangelist'),
#   (-0.05618552, 'correspondent'),
#   (-0.056026176, 'nun'),
#   (-0.05575011, 'aide'),
#   (-0.054137003, 'preacher'),
#   (-0.051874723, 'solicitor_general'),
#   (-0.051463068, 'accountant'),
#   (-0.05085372, 'fisherman'),
#   (-0.049876273, 'financier'),
#   (-0.047064908, 'gangster'),
#   (-0.04637759, 'researcher'),
#   (-0.034095436, 'broadcaster'),
#   (-0.033337533, 'ballplayer'),
#   (-0.032071903, 'businesswoman'),
#   (0.0014490522, 'philanthropist'),
#   (0.005909577, 'plumber')])

# %%
# analogies gender
a_gender_debiased = E.best_analogies_dist_thresh(v_gender, max_words=1000)

for (a,b,c) in a_gender_debiased:
    print(a+"-"+b)
# Out:
# Computing neighbors
# Mean: 998.926
# Median: 999.0
# she-minutes
# day-minute
# women-between
# woman-age
# country-prices
# wife-income
# serve-especially
# court-members
# stay-probably
# running-most
# series-charged
# medical-situation
# remain-more
# tournament-highest
# morning-performance
# afternoon-information
# he-crisis
# planned-only
# show-time
# international-member
# world-all
# like-senior
# player-further
# find-chance
# applications-quite
# prison-every
# school-years
# firm-however
# come-won
# her-us
# children-child
# equipment-longer
# program-attention
# policy-point
# would-nothing
# pay-getting
# want-very
# continues-likely
# statements-provides
# buy-sale
# named-added
# title-at
# played-role
# question-winner
# served-limited
# open-charge
# filed-least
# base-source
# proposed-posted
# food-less
# summer-quickly
# scheduled-position
# website-personal
# test-per
# financial-products
# died-can
# track-failed
# forces-few
# old-funds
# major-involved
# field-points
# kept-hold
# does-do
# department-something
# hearing-meeting
# playing-together
# comment-per_cent
# development-result
# software-quality
# education-product
# black-white
# trading-traffic
# expected-receive
# drive-cash
# phone-spot
# military-social
# building-particularly
# remains-consumer
# land-no
# various-above
# driver-need
# took-take
# are-sales
# that-opportunity
# city-kind
# mother-not
# him-agreement
# assets-better
# name-amount
# its-score
# weekend-beginning
# site-common
# sector-even
# house-room
# programs-anything
# ahead-pressure
# hard-goals
# showed-best
# hour-step
# legal-below
# demand-required
# released-increased
# call-interview
# lives-helped
# clear-from
# businesses-times
# film-war
# seven-plant
# closed-again
# shows-changes
# money-over
# today-pick
# bill-total
# jobs-win
# people-person
# record-right
# quarter-half
# later-second
# working-work
# front-head
# those-where
# days-the
# areas-important
# companies-action
# ways-another
# success-change
# forward-additional
# company-share
# late-credit
# been-taken
# means-also
# talk-part
# attacks-based
# organizations-staff
# said-includes
# main-starting
# organization-around
# host-fifth
# families-including
# value-price
# am-already
# men-his
# before-first
# free-officer
# network-investigation
# night-year
# paid-space
# because-about
# within-once
# report-president
# sell-now
# play-save
# match-full
# fell-moved
# found-lost
# follow-then
# car-interest
# huge-positive
# met-with
# eight-left
# countries-back
# talks-charges
# instead-advantage
# my-what
# issued-million
# themselves-itself
# plays-bring
# following-tax
# looking-look
# teams-both
# construction-content
# wrote-understand
# planning-political
# job-move
# four-five
# official-cents
# fall-vote
# news-break
# along-these
# center-return
# biggest-largest
# mean-made
# shooting-needs
# due-rights
# near-moving
# always-immediately
# create-everything
# me-foot
# government-national
# despite-fourth
# saw-past
# schools-different
# residents-troops
# questions-lower
# created-told
# wanted-wants
# earnings-profit
# love-operating
# large-small
# light-way
# general-some
# fund-next
# players-power
# patients-customers
# cars-driving
# release-several
# list-having
# spent-nearly
# hours-an
# hope-hopes
# basis-details
# reason-fact
# appeared-when
# games-returned
# drug-low
# line-top
# private-media
# issue-issues
# toward-although
# reached-average
# were-you
# rose-example
# sold-loss
# felt-sense
# living-community
# put-makes
# may-could
# gone-them
# going-how
# hospital-bit
# bank-away
# great-good
# funding-make
# final-third
# man-father
# on-victory
# business-account
# long-high
# rest-trip
# gets-get
# continued-increase
# marketing-shares
# end-stage
# it-last
# be-place
# see-too
# called-future
# spending-revenue
# allowed-dollars
# spokesman-director
# why-as
# study-almost
# in-among
# allow-let
# fire-property
# goes-went
# whether-body
# scoring-yards
# takes-taking
# known-well
# stand-pass
# received-looked
# build-signed
# friends-is
# couple-leaders
# defense-side
# across-throughout
# accused-owner
# continue-current
# key-levels
# comes-which
# life-use
# dead-just
# strong-many
# chairman-industry
# race-college
# reported-movie
# public-gas
# while-began
# research-budget
# order-leader
# thousands-police
# available-currently
# television-simply
# month-ever
# league-real
# energy-treatment
# finish-higher
# ready-worth
# economy-young
# runs-capital
# game-decision
# everyone-happy
# recent-often
# comments-start
# markets-ensure
# say-so
# costs-cost
# provided-provide
# far-earlier
# asked-without
# big-up
# being-lead
# meet-turned
# projects-users
# star-foreign
# considered-close
# miles-cases
# week-addition
# music-popular
# nine-or
# features-efforts
# trade-here
# months-results
# tough-early
# market-party
# forced-compared
# coach-insurance
# impact-region
# fight-problem
# lot-post
# student-new
# death-parents
# anyone-any
# ground-law
# know-done
# someone-if
# authorities-officials
# yesterday-risk
# think-economic
# cut-previous
# designed-visit
# their-former
# rise-election
# conference-either
# training-begin
# form-one
# heart-home
# must-security
# board-care
# had-might
# opening-campaign
# thing-coming
# much-own
# vehicle-investment
# into-plan
# management-control
# announced-competition
# cause-attorney
# approved-raise
# include-became
# saying-similar
# opened-help
# executive-operations
# numbers-number
# judge-such
# tried-during
# hand-hands
# actually-entire
# rather-was
# contract-experience
# thought-given
# fuel-seen
# course-set
# still-heard
# decided-has
# ability-effort
# rate-stock
# possible-potential
# single-double
# reports-conditions
# groups-started
# brought-beat
# date-period
# straight-book
# workers-manager
# consumers-investors
# short-water
# view-access
# design-response
# ended-until
# inside-outside
# online-travel
# offers-using
# six-three
# seems-used
# each-under
# council-who
# project-commercial
# contact-our
# attack-force
# dollar-ask
# concerns-passed
# event-term
# giving-gave
# overall-down
# process-environment
# idea-search
# states-state
# growth-growing
# for-present
# practice-live
# words-believe
# latest-raised
# plans-through
# hits-hit
# tell-by
# fiscal-John
# complete-whole
# feet-son
# doing-making
# ball-net
# against-claims
# employees-difficult
# officers-himself
# agency-ago
# become-turn
# debt-system
# happen-things
# sure-your
# football-significant
# shot-reach
# keep-safety
# killed-winning
# bad-out
# though-needed
# face-will
# enough-pm
# related-leading
# committee-chief
# came-soon
# agreed-systems
# trying-than
# county-team
# offering-nation
# billion-they
# really-go
# violence-problems
# offer-included
# special-same
# focus-feel
# scored-there
# adding-led
# production-mobile
# range-store
# should-this
# guys-case
# weeks-recently
# finished-level
# have-serious
# challenge-federal
# kids-group
# support-activities
# deal-benefit
# since-banks
# completed-non
# season-solutions
# area-local
# air-pretty
# family-town
# works-other
# service-offered
# regular-followed
# matter-unit
# whose-happened
# but-homes
# students-two
# rates-rules
# others-events
# data-video
# class-built
# try-calls
# services-benefits
# district-round
# review-run
# did-expect
# address-career
# sign-successful
# knew-history
# after-club
# held-stop
# sent-statement
# leave-evidence
# trial-arrested
# terms-never
# we-off
# global-annual
# goal-road
# yet-dropped
# providing-reduce
# according-percent
# technology-easy
# health-improve
# fans-says
# read-give
# little-able
