# %% [markdown]
# ## Hands-on Tutorial: Quantifying and Reducing Gender Stereotypes in Word Embeddings

# %% [markdown]
# Ensuring fairness in algorithmically-driven decision-making is important to avoid inadvertent cases of bias and perpetuation of harmful stereotypes. However, modern natural language processing techniques, which learn model parameters based on data, might rely on implicit biases presented in the data to make undesirable stereotypical associations. Such a danger is facing us with word embedding, a popular framework to represent text data as vectors which has been used in many machine learning and natural language processing tasks. Recent results ([1](https://arxiv.org/abs/1607.06520), [2](https://arxiv.org/abs/1608.07187)) show that even word embeddings trained on Google News articles exhibit female/male gender stereotypes to a disturbing extent. This raises concerns because of their widespread use, as we describe, often tends to amplify these biases.
#
# In the following, we provide step-by-step instructions to demonstrate and quanitfy the biases in word embedding.

# %%
# Setup:
# Clone the code repository from https://github.com/tolga-b/debiaswe.git
# mkdir debiaswe_tutorial
# cd debiaswe_tutorial
# git clone https://github.com/tolga-b/debiaswe.git

# To reduce the time of downloading data, we provide as subset of GoogleNews-vectors in the following location:
# https://drive.google.com/file/d/1NH6jcrg8SXbnhpIXRIXF_-KUE7wGxGaG/view?usp=sharing

# For full embeddings:
# Download embeddings at https://github.com/tolga-b/debiaswe and put them on the following directory
# embeddings/GoogleNews-vectors-negative300-hard-debiased.bin
# embeddings/GoogleNews-vectors-negative300.bin

# %%
from __future__ import print_function, division
# %matplotlib inline
from matplotlib import pyplot as plt
import json
import random
import numpy as np

import debiaswe as dwe
import debiaswe.we as we
from debiaswe.we import WordEmbedding
from debiaswe.data import *

# %% [markdown]
# ## Part 1: Gender Bias in Word Embedding
#
#
# ### Step 1: Load data
# We first load the word embedding trained on a corpus of Google News texts consisting of 3 million English words and terms. The embedding maps each word into a 300-dimension vector.

# %%
# load google news word2vec
E = WordEmbedding('./embeddings/w2v_gnews_small.txt')
# E = WordEmbedding('./embeddings/GoogleNews-vectors-negative300.bin')

# load data
gender_specific_words, defs, equalize_pairs, profession_words = load_data(E.words)
# Out:
# Creating embedding from file: C:\Users\kylia\Documents\Msc AI jaar 1\FACTAI\FactAI\replication\embeddings\w2v_gnews_small.txt
# 26423 words of dimension 300 : in, for, that, is, ..., Jay, Leroy, Brad, Jermaine
# Embedding shape: (26423, 300)

# %%
# Extra test cell, remove later
print(np.linalg.norm(E.vecs, axis=1).mean())
print(E.vecs.mean())

from sklearn.manifold import TSNE
tsne = TSNE(n_components=2).fit_transform(E.vecs[:2000])
plt.scatter(tsne[:,0], tsne[:,1], s=10)
plt.show()
# Out:
# 1.0
# -0.00095485727

# %% [markdown]
# ### Step 2: Define gender direction
#
# We define gender direction by the direciton of she - he because they are frequent and do not have fewer alternative word senses (e.g., man can also refer to mankind). In the paper, we discuss alternative approach for defining gender direction (e.g., using PCA).

# %%
# gender direction
# v_gender = E.diff('she', 'he')

v_gender = we.doPCA(defs, E).components_[0]

# %% [markdown]
# ### Step 3: Generating analogies of "Man: x :: Woman : y"
#
# We show that the word embedding model generates gender-streotypical analogy pairs.
# To generate the analogy pairs, we use the analogy score defined in our paper. This score finds word pairs that are well aligned with gender direction as well as within a short distance from each other to preserve topic consistency.

# %%
# analogies gender
a_gender = E.best_analogies_dist_thresh(v_gender, thresh=1)

we.viz(a_gender)
# Out:
# Computing neighbors
# Mean: 10.219732808538016
# Median: 7.0
# (135018, 300)
#    0                      herself | himself                      0.94
#    1                          she | he                           0.94
#    2                          her | his                          0.91
#    3                        woman | man                          0.82
#    4                     daughter | son                          0.74
#    5                         girl | boy                          0.74
#    6                      actress | actor                        0.72
#    7                businesswoman | businessman                  0.70
#    8                       sister | brother                      0.69
#    9                       mother | father                       0.69
#   10                  spokeswoman | spokesman                    0.67
#   11                      heroine | hero                         0.67
#   12                   chairwoman | chairman                     0.67
#   13                      sisters | brothers                     0.67
#   14                        girls | boys                         0.65
#   15                        niece | nephew                       0.64
#   16                 councilwoman | councilman                   0.62
#   17                          gal | dude                         0.61
#   18                         aunt | uncle                        0.60
#   19                granddaughter | grandson                     0.59
#   20                        queen | king                         0.59
#   21                   motherhood | fatherhood                   0.59
#   22                   schoolgirl | schoolboy                    0.59
#   23                         Anne | John                         0.58
#   24                        women | men                          0.58
#   25                  twin_sister | twin_brother                 0.58
#   26                       petite | lanky                        0.58
#   27                    matriarch | patriarch                    0.56
#   28               ovarian_cancer | prostate_cancer              0.56
#   29                          mom | dad                          0.55
#   30                      soprano | baritone                     0.55
#   31                      lesbian | gay                          0.53
#   32                    daughters | sons                         0.52
#   33                      mothers | fathers                      0.52
#   34                  grandmother | grandfather                  0.52
#   35                      husband | younger_brother              0.51
#   36                     sorority | fraternity                   0.51
#   37                         lady | gentleman                    0.49
#   38                       blouse | shirt                        0.49
#   39                       queens | kings                        0.48
#   40                      grandma | grandpa                      0.48
#   41                         diva | superstar                    0.47
#   42                         gals | dudes                        0.46
#   43                      goddess | god                          0.46
#   44               granddaughters | grandsons                    0.46
#   45                        mommy | kid                          0.45
#   46                        Aisha | Jamal                        0.45
#   47                     waitress | waiter                       0.44
#   48                        Sarah | Matthew                      0.44
#   49                     softball | baseball                     0.44
#   50                         mare | gelding                      0.44
#   51                        filly | colt                         0.44
#   52                         Jill | Greg                         0.43
#   53                   volleyball | football                     0.43
#   54                  hairdresser | barber                       0.43
#   55                  girlfriends | buddies                      0.43
#   56                        aunts | uncles                       0.42
#   57                    actresses | actors                       0.42
#   58                         hair | beard                        0.42
#   59                      heiress | magnate                      0.42
#   60                     feminine | manly                        0.42
#   61                     princess | prince                       0.41
#   62            interior_designer | architect                    0.41
#   63                       ladies | gentlemen                    0.41
#   64                          bra | pants                        0.41
#   65                         moms | dads                         0.41
#   66                congresswoman | congressman                  0.39
#   67                          nun | priest                       0.39
#   68                       nieces | nephews                      0.39
#   69                         babe | fella                        0.39
#   70                     fabulous | terrific                     0.39
#   71                     vocalist | guitarist                    0.39
#   72                        blond | burly                        0.38
#   73                    housewife | shopkeeper                   0.38
#   74                     feminism | conservatism                 0.38
#   75                      starlet | youngster                    0.38
#   76                       sewing | carpentry                    0.38
#   77                        sassy | snappy                       0.38
#   78                    glamorous | flashy                       0.38
#   79                         hers | yours                        0.38
#   80                 stepdaughter | stepson                      0.38
#   81                        bitch | bastard                      0.38
#   82                       feisty | mild_mannered                0.38
#   83                      topless | shirtless                    0.37
#   84                    childhood | boyhood                      0.37
#   85                     gorgeous | brilliant                    0.37
#   86                        nurse | physician                    0.37
#   87                   compatriot | countryman                   0.37
#   88                wedding_dress | tuxedo                       0.37
#   89                     charming | affable                      0.36
#   90                       breast | prostate                     0.36
#   91                      fillies | colts                        0.36
#   92                      females | males                        0.35
#   93                      handbag | briefcase                    0.35
#   94                       lovely | magnificent                  0.35
#   95                        kinda | guy                          0.35
#   96                        whore | coward                       0.35
#   97                     siblings | elder_brother                0.35
#   98                        salon | barbershop                   0.35
#   99                       female | male                         0.35
#  100                    headscarf | turban                       0.35
#  101                        hubby | pal                          0.35
#  102                         mums | blokes                       0.34
#  103                       singer | frontman                     0.34
#  104                     cupcakes | pizzas                       0.34
#  105                    vocalists | trumpeter                    0.34
#  106                     feminist | liberal                      0.34
#  107                         kids | guys                         0.34
#  108                  salesperson | salesman                     0.33
#  109                         sexy | nerdy                        0.33
#  110                breast_cancer | lymphoma                     0.33
#  111                     estrogen | testosterone                 0.33
#  112                     children | youngsters                   0.33
#  113                       vagina | penis                        0.33
#  114                     adorable | goofy                        0.33
#  115                     cheerful | jovial                       0.33
#  116                        witch | demon                        0.32
#  117                       skirts | shorts                       0.32
#  118                       blonde | blond                        0.32
#  119                      convent | cathedral                    0.32
#  120                         bras | trousers                     0.32
#  121                      dresses | shirts                       0.32
#  122                     luscious | crisp                        0.32
#  123                       giggle | chuckle                      0.32
#  124                         gown | blazer                       0.32
#  125                     giggling | grinning                     0.32
#  126                      Latonya | Leroy                        0.31
#  127                    feminists | liberalism                   0.31
#  128                       Laurie | Brett                        0.31
#  129                   stepmother | eldest_son                   0.31
#  130                    cosmetics | pharmaceuticals              0.31
#  131                      netball | rugby                        0.31
#  132                    beautiful | majestic                     0.31
#  133                          wig | mustache                     0.31
#  134                         pink | blue                         0.31
#  135                         them | him                          0.30
#  136                       uterus | intestine                    0.30
#  137                    violinist | virtuoso                     0.30
#  138                      midwife | doctor                       0.30
#  139                        dolls | replicas                     0.30
#  140                    wonderful | great                        0.30
#  141                         nuns | monk                         0.30
#  142             registered_nurse | paramedic                    0.30
#  143                      breasts | genitals                     0.30
#  144                        boobs | ass                          0.29
#  145                        nanny | chauffeur                    0.29
#  146                       beauty | grandeur                     0.29
#  147                  middle_aged | bearded                      0.29
#  148                   delightful | superb                       0.29
#  149           physical_therapist | orthopedic_surgeon           0.29
#  150                teenage_girls | youths                       0.29
#  151                        dress | wearing                      0.29
#  152                    rebounder | playmaker                    0.29
#  153                     lingerie | menswear                     0.29
#  154                      hostess | bartender                    0.29
#  155                      friends | buddy                        0.29
#  156                    mammogram | colonoscopy                  0.29
#  157                    boyfriend | stepfather                   0.29
#  158                 spokespeople | spokesmen                    0.29
#  159                     alluring | intriguing                   0.29
#  160                     swimwear | sportswear                   0.29
#  161                     implants | stents                       0.29
#  162                schoolteacher | carpenter                    0.29
#  163                       sultry | mellow                       0.28
#  164                       sexism | racism                       0.28
#  165                      singers | guitarists                   0.28
#  166                      sensual | moody                        0.28
#  167                   enchanting | splendid                     0.28
#  168                 practicality | durability                   0.28
#  169                  captivating | masterful                    0.28
#  170                         cute | clever                       0.28
#  171                     gymnasts | wrestlers                    0.28
#  172                        bride | groom                        0.28
#  173                     lesbians | homosexuals                  0.28
#  174                   cheesecake | pizza                        0.28
#  175            singer_songwriter | musician                     0.28
#  176                     ethereal | brooding                     0.28
#  177                      gymnast | wrestler                     0.28
#  178                       libero | midfielders                  0.28
#  179           guidance_counselor | headmaster                   0.28
#  180                 teenage_girl | teenager                     0.27
#  181                     rehearse | improvise                    0.27
#  182                   midfielder | winger                       0.27
#  183                   hysterical | comical                      0.27
#  184                   judgmental | arrogant                     0.27
#  185                      giggles | chuckles                     0.27
#  186                        gowns | robes                        0.27
#  187                   servicemen | veterans                     0.27
#  188                   gymnastics | judo                         0.27
#  189                   boyfriends | friends                      0.27
#  190                    cigarette | cigar                        0.26
#  191                       baking | roasting                     0.26
#  192                       lovers | aficionados                  0.26
#  193                 choreography | footwork                     0.26
#  194                    burlesque | rock_n_roll                  0.26
#  195                     kindness | humility                     0.26
#  196                      pianist | maestro                      0.26
#  197                       sexist | racist                       0.26
#  198                      kittens | neutered                     0.26
#  199                        mares | stallion                     0.26
#  200                     silicone | polymer                      0.26
#  201              eating_disorder | alcoholism                   0.26
#  202                      cupcake | donut                        0.26
#  203                  housekeeper | janitor                      0.26
#  204                    designers | architects                   0.26
#  205                         mama | daddy                        0.26
#  206                      panties | socks                        0.26
#  207                       hurler | starter                      0.26
#  208                  chairperson | chaired                      0.26
#  209                     novelist | philosopher                  0.26
#  210                    backcourt | swingman                     0.25
#  211                     stroller | bicycle                      0.25
#  212            male_counterparts | counterparts                 0.25
#  213                        flute | trombone                     0.25
#  214                         cubs | lions                        0.25
#  215                     crafting | drafting                     0.25
#  216                        manga | comic_books                  0.25
#  217                    presenter | broadcaster                  0.25
#  218                     husbands | wives                        0.25
#  219                      kissing | shaking_hands                0.25
#  220                        lupus | multiple_myeloma             0.25
#  221                        cakes | sausages                     0.25
#  222                        latex | rubber                       0.25
#  223                       hooker | fullback                     0.25
#  224                        bingo | gambling                     0.25
#  225                         veil | cloak                        0.25
#  226                      dancers | drummers                     0.25
#  227                       gender | racial                       0.25
#  228                       sobbed | grinned                      0.25
#  229                 prostitution | drug_trafficking             0.25
#  230                     antiques | memorabilia                  0.25
#  231                   hair_salon | pizzeria                     0.25
#  232                     costumes | props                        0.25
#  233                       vocals | drummer                      0.25
#  234                       fiance | cousin                       0.25
#  235                    intuition | instincts                    0.25
#  236             eating_disorders | substance_abuse              0.24
#  237                       cougar | wolves                       0.24
#  238                       Carrie | Laurie                       0.24
#  239                     freshmen | rookies                      0.24
#  240                      amazing | unbelievable                 0.24
#  241                     artistry | genius                       0.24
#  242             flight_attendant | pilots                       0.24
#  243                         teen | youth                        0.24
#  244                     sweaters | jerseys                      0.24
#  245                        smile | grin                         0.24
#  246                       layups | downfield                    0.24
#  247                    harmonies | riffs                        0.24
#  248                 osteoporosis | atherosclerosis              0.24
#  249                       cheery | amiable                      0.24
#  250                      outfits | garb                         0.24
#  251                         beau | pals                         0.24
#  252                    hairstyle | facial_hair                  0.24
#  253                   terrifying | fearsome                     0.24
#  254           child_endangerment | aggravated_assault           0.24
#  255               figure_skating | hockey                       0.24
#  256                     teenager | lad                          0.24
#  257                      jewelry | collectibles                 0.24
#  258                         chic | minimalist                   0.24
#  259                        duets | saxophonist                  0.24
#  260                       worker | foreman                      0.24
#  261                         glam | retro                        0.24
#  262                      uptight | cocky                        0.24
#  263                      sweater | jersey                       0.24
#  264                       rapist | thug                         0.24
#  265              cervical_cancer | colorectal_cancer            0.24
#  266                         hugs | shook_hands                  0.24
#  267                    masculine | macho                        0.24
#  268                        scarf | jacket                       0.24
#  269                          hen | cock                         0.24
#  270                      glitter | confetti                     0.24
#  271                         grad | alumnus                      0.24
#  272              romantic_comedy | flick                        0.24
#  273                meter_hurdles | yard_dash                    0.24
#  274                      cooking | grill                        0.24
#  275                        maids | servants                     0.24
#  276                    exclaimed | quipped                      0.24
#  277               unconventional | unorthodox                   0.24
#  278                         foal | thoroughbred                 0.23
#  279                    seductive | mesmerizing                  0.23
#  280          assistant_professor | professor_emeritus           0.23
#  281                   classmates | teammates                    0.23
#  282                      putback | yard_touchdown               0.23
#  283                        retro | throwback                    0.23
#  284                underclassmen | players                      0.23
#  285                      baseman | offensive_lineman            0.23
#  286                  transgender | homosexual                   0.23
#  287              unassisted_goal | deflected                    0.23
#  288                   inadequate | ineffective                  0.23
#  289                     elegance | style                        0.23
#  290                    tamoxifen | statins                      0.23
#  291                        anime | videogames                   0.23
#  292                 giant_slalom | skied                        0.23
#  293                    menopause | heart_disease                0.23
#  294                    sophomore | pounder                      0.23
#  295                        lover | enthusiast                   0.23
#  296                       plucky | hapless                      0.23
#  297                   dispatcher | patrolman                    0.23
#  298                    classmate | teammate                     0.23
#  299                         cats | pigeons                      0.23
#  300                     midwives | doctors                      0.23
#  301             cosmetic_surgery | surgery                      0.23
#  302                       feline | bulldog                      0.23
#  303                      apparel | sporting_goods               0.23
#  304                      warship | destroyer                    0.23
#  305                  breast_milk | sperm                        0.23
#  306                 delightfully | brilliantly                  0.23
#  307                   cigarettes | cigars                       0.23
#  308                       choral | composer                     0.23
#  309                 ex_boyfriend | friend                       0.23
#  310                heartbreaking | humbling                     0.23
#  311                     seatbelt | wearing_helmet               0.23
#  312                     sprinter | speedster                    0.23
#  313                    regionals | playoffs                     0.22
#  314                 spokesperson | statement                    0.22
#  315                      realtor | builder                      0.22
#  316                         lamb | butcher                      0.22
#  317                   ultrasound | x_ray                        0.22
#  318                       dancer | entertainer                  0.22
#  319                       gossip | rumor                        0.22
#  320                      stalker | pedophile                    0.22
#  321                        cried | chuckled                     0.22
#  322                  self_esteem | morale                       0.22
#  323                    elegantly | superbly                     0.22
#  324                   housewives | middle_aged                  0.22
#  325                    librarian | curator                      0.22
#  326                   frontcourt | playmakers                   0.22
#  327                  free_throws | touchdown_pass               0.22
#  328                      singing | rapping                      0.22
#  329                    bartender | bouncer                      0.22
#  330                      pitcher | lefthander                   0.22
#  331               transformative | visionary                    0.22
#  332                    paralegal | accountant                   0.22
#  333                     clarinet | saxophone                    0.22
#  334                   empowering | motivating                   0.22
#  335                    auditions | tryout                       0.22
#  336                     wellness | fitness                      0.22
#  337                     neurotic | eccentric                    0.22
#  338                   internship | apprenticeship               0.22
#  339                 pediatrician | cardiologist                 0.22
#  340                      sobbing | shouted                      0.22
#  341                      vampire | superhero                    0.22
#  342                          bun | burgers                      0.22
#  343                       blokes | bloke                        0.22
#  344                     anorexia | depression                   0.22
#  345                   incumbents | incumbent                    0.22
#  346                        raped | sexually_abusing             0.22
#  347                    mentoring | mentor                       0.22
#  348                  provocative | incendiary                   0.22
#  349                      cashier | robber                       0.22
#  350                         gosh | heck                         0.22
#  351                        rapes | crimes                       0.22
#  352                       nurses | physicians                   0.21
#  353                     collagen | cartilage                    0.21
#  354                       hitter | southpaw                     0.21
#  355                    pregnancy | gestation                    0.21
#  356                        layup | yarder                       0.21
#  357                    sexuality | homosexuality                0.21
#  358                  resourceful | wily                         0.21
#  359                     plunging | slumping                     0.21
#  360                    badminton | snooker                      0.21
#  361                       shrill | louder                       0.21
#  362                      romance | friendship                   0.21
#  363                       clique | cronies                      0.21
#  364                   delectable | sublime                      0.21
#  365                    terrified | mad                          0.21
#  366                      Allison | Todd                         0.21
#  367                     thirteen | eleven                       0.21
#  368                      campers | camp                         0.21
#  369                       curves | curved                       0.21
#  370                      beloved | legendary                    0.21
#  371                       cloned | clone                        0.21
#  372                    exercises | drills                       0.21
#  373                       steals | tackles                      0.21
#  374                   starvation | famine                       0.21
#  375                       vulgar | profane                      0.21
#  376              silver_medalist | compatriot                   0.21
#  377                entrepreneurs | businessmen                  0.21
#  378                       walker | crutches                     0.21
#  379                      closets | lockers                      0.21
#  380             graphic_designer | cartoonist                   0.21
#  381                        rower | skipper                      0.21
#  382                     artisans | craftsmen                    0.21
#  383                experimenting | tinkering                    0.21
#  384                    shortstop | defensive_lineman            0.21
#  385                      couples | married_couples              0.21
#  386                    horrified | incensed                     0.21
#  387                       memoir | autobiography                0.21
#  388                    prettiest | finest                       0.21
#  389                        fairy | magical                      0.21
#  390                     folklore | legend                       0.21
#  391                    scripture | disciples                    0.21
#  392                        satin | leather                      0.21
#  393                  coordinator | manager                      0.21
#  394                    counselor | adviser                      0.21
#  395                       chicks | ducks                        0.21
#  396               middle_blocker | leadoff_hitter               0.21
#  397                      minivan | pickup_truck                 0.21
#  398                    activists | supporters                   0.21
#  399                       caring | selfless                     0.21
#  400                       thighs | biceps                       0.21
#  401                     designed | engineered                   0.21
#  402                love_triangle | saga                         0.21
#  403                 insecurities | frustrations                 0.21
#  404                     cookbook | tome                         0.21
#  405                        mills | steel_mills                  0.20
#  406                  ice_skating | skateboarding                0.20
#  407             critical_acclaim | plaudits                     0.20
#  408                      skirted | evaded                       0.20
#  409                 resignations | sacking                      0.20
#  410               animal_cruelty | dogfighting                  0.20
#  411                        purse | wallet                       0.20
#  412                     abducted | gunned_down                  0.20
#  413                    energetic | charismatic                  0.20
#  414                    rehearsal | improvisation                0.20
#  415                     beautify | rehabilitate                 0.20
#  416                  celebrities | superstars                   0.20
#  417                    turquoise | navy_blue                    0.20
#  418                       celebs | stars                        0.20
#  419            holistic_approach | approach                     0.20
#  420                    cocktails | beers                        0.20
#  421                       adored | revered                      0.20
#  422                   shimmering | gleaming                     0.20
#  423                      interns | fellows                      0.20
#  424                  contestants | hopefuls                     0.20
#  425                      smitten | enamored                     0.20
#  426                      ribbons | plaques                      0.20
#  427                       golfer | sportsman                    0.20
#  428                         sang | chanted                      0.20
#  429                    demeaning | disrespectful                0.20
#  430                     clothing | merchandise                  0.20
#  431                       flower | ornamental                   0.20
#  432                   strawberry | potato                       0.20
#  433                     makeover | revamp                       0.20
#  434                   courageous | honorable                    0.20
#  435                 demonstrates | underlines                   0.20
#  436                   sophomores | offensive_linemen            0.20
#  437                       unsafe | dangerous                    0.20
#  438                  storyteller | magician                     0.20
#  439                    thousands | tens                         0.20
#  440                 doubleheader | game                         0.20
#  441                     hormonal | metabolic                    0.20
#  442                     watchers | pundits                      0.20
#  443                       bubbly | champagne                    0.20
#  444                      thyroid | inflammation                 0.20
#  445               anthropologist | historian                    0.20
#  446                  overwhelmed | humbled                      0.20
#  447                    boutiques | retail_outlets               0.20
#  448                         poem | eulogy                       0.20
#  449               nerve_wracking | frustrating                  0.20
#  450                       export | import                       0.20
#  451                     freshman | redshirt_freshman            0.20
#  452                       creepy | menacing                     0.20
#  453                      bondage | shackles                     0.20
#  454                 foul_trouble | defensively                  0.20
#  455                    therapist | neurologist                  0.20
#  456                       horrid | mediocre                     0.20
#  457                    workshops | sessions                     0.20
#  458                   articulate | thinker                      0.20
#  459                    tenacious | hard_nosed                   0.20
#  460                       drinks | beer                         0.20
#  461                       violin | guitar                       0.20
#  462                     quilting | stained_glass                0.20
#  463                     boutique | shop                         0.20
#  464                   mysterious | enigmatic                    0.20
#  465                     soldiers | platoon                      0.20
#  466                      catcher | lineman                      0.20
#  467                     luminous | dazzling                     0.20
#  468                        dayer | seamer                       0.20
#  469                  backstretch | straightaway                 0.20
#  470                    behaviors | tendencies                   0.20
#  471               attractiveness | competitiveness              0.20
#  472                      vibrant | dynamic                      0.20
#  473                   incredibly | obviously                    0.20
#  474                   scandalous | disgraceful                  0.20
#  475                      firings | firing                       0.19
#  476                    sergeants | lieutenants                  0.19
#  477                 complainants | accusers                     0.19
#  478                    homemaker | schoolteacher                0.19
#  479              gender_equality | poverty_alleviation          0.19
#  480                    underpass | tunnel                       0.19
#  481                   characters | villain                      0.19
#  482                   delicately | deftly                       0.19
#  483                     critters | beasts                       0.19
#  484                     advocate | proponent                    0.19
#  485                        soaps | sitcoms                      0.19
#  486                    complicit | culpable                     0.19
#  487                           ok | alright                      0.19
#  488             interim_dividend | dividends                    0.19
#  489                     garments | apparel                      0.19
#  490                     downsize | restructure                  0.19
#  491             oncoming_traffic | swerving                     0.19
#  492                           ex | former                       0.19
#  493                 manipulative | cunning                      0.19
#  494            sexual_harassment | misconduct                   0.19
#  495                       embryo | embryonic                    0.19
#  496                    endearing | likeable                     0.19
#  497                         rape | attempted_murder             0.19
#  498                       blooms | buds                         0.19
#  499                     stripper | strippers                    0.19

# %% [markdown]
# ### Step 4: Analyzing gender bias in word vectors asscoiated with professions
#
# Next, we show that many occupations are unintendedly associated with either male of female by projecting their word vectors onto the gender dimension.
#
# The script will output the profession words sorted with respect to the projection score in the direction of gender.

# %%
# profession analysis gender
sp = E.profession_stereotypes(profession_words, v_gender)
# Out:
#                 Female                |                 Male
# -----------------------------------------------------------------------------
# 0.38                    businesswoman | maestro                        -0.244
# 0.379                         actress | protege                        -0.236
# 0.378                       housewife | statesman                      -0.222
# 0.323                       homemaker | businessman                    -0.219
# 0.308                           nurse | sportsman                      -0.209
# 0.302                registered_nurse | philosopher                    -0.196
# 0.297                        waitress | marksman                       -0.192
# 0.28                     receptionist | skipper                        -0.187
# 0.278                       socialite | financier                      -0.183
# 0.277                       librarian | architect                      -0.177
# 0.272                            maid | magician                       -0.172
# 0.265                             nun | trumpeter                      -0.172
# 0.261                       ballerina | major_leaguer                   -0.16
# 0.233                           nanny | salesman                       -0.157
# 0.232                       paralegal | captain                        -0.154
# 0.218                     hairdresser | mechanic                       -0.153
# 0.211                     housekeeper | warrior                        -0.152
# 0.203                      bookkeeper | lieutenant                     -0.152
# 0.199                         stylist | gangster                        -0.15
# 0.198               interior_designer | fighter_pilot                  -0.148

# %% [markdown]
# ## Part 2 Racial Bias
#
# ### Step 5: Define racial direction
# We define racial direction based on the common names in different Demographic groups.

# %%
names = ["Emily", "Aisha", "Anne", "Keisha", "Jill", "Tamika", "Allison", "Lakisha", "Laurie", "Tanisha", "Sarah",
         "Latoya", "Meredith", "Kenya", "Carrie", "Latonya", "Kristen", "Ebony", "Todd", "Rasheed", "Neil", "Tremayne",
         "Geoffrey", "Kareem", "Brett", "Darnell", "Brendan", "Tyrone", "Greg", "Hakim", "Matthew", "Jamal", "Jay",
         "Leroy", "Brad", "Jermaine"]
names_group1 = [names[2 * i] for i in range(len(names) // 2)]
names_group2 = [names[2 * i + 1] for i in range(len(names) // 2)]

# %%
# racial direction
vs = [sum(E.v(w) for w in names) for names in (names_group2, names_group1)]
vs = [v / np.linalg.norm(v) for v in vs]

v_racial = vs[1] - vs[0]
v_racial = v_racial / np.linalg.norm(v_racial)

# %% [markdown]
# ### Step 6: Generating racial biased analogies
#
# Similar to Step 3, we generate analogies that align with the racial dimension.

# %%
# racial analogies
a_racial = E.best_analogies_dist_thresh(v_racial)
we.viz(a_racial)
# Out:
#    0                        Sarah | Keisha                       0.67
#    1                   defensemen | cornerbacks                  0.37
#    2                      hipster | hip_hop                      0.35
#    3                       punter | cornerback                   0.35
#    4            singer_songwriter | rapper                       0.34
#    5                   defenseman | defensive_tackle             0.34
#    6                   pole_vault | triple_jump                  0.33
#    7                    musicians | artistes                     0.32
#    8                     musician | artiste                      0.32
#    9                      catcher | wide_receiver                0.31
#   10                  rock_n_roll | reggae                       0.30
#   11                       kicker | kick_returner                0.30
#   12                       tavern | barbershop                   0.30
#   13              freestyle_relay | meter_hurdles                0.30
#   14                   lefthander | swingman                     0.29
#   15                        bacon | fried_chicken                0.29
#   16                      artists | rappers                      0.29
#   17                    equipment | equipments                   0.29
#   18                       hockey | basketball                   0.28
#   19                         wool | cotton                       0.28
#   20              unassisted_goal | layup                        0.28
#   21                   chocolates | sweets                       0.28
#   22                        buddy | cousin                       0.27
#   23                       priest | preacher                     0.27
#   24                         blue | black                        0.26
#   25                 medley_relay | meter_dash                   0.26
#   26                       quirky | funky                        0.26
#   27                        rabbi | imam                         0.26
#   28                       grapes | mango                        0.26
#   29           telecommunications | telecommunication            0.26
#   30                     pitchers | defensive_linemen            0.25
#   31                     passages | verses                       0.25
#   32                           er | o                            0.25
#   33                     acoustic | soulful                      0.25
#   34                      punting | punt_returns                 0.25
#   35                       thefts | armed_robbery                0.25
#   36                          bar | nightclub                    0.25
#   37                         digs | rebounds                     0.24
#   38                         Greg | Geoffrey                     0.24
#   39                      cellist | saxophonist                  0.24
#   40                       smarts | quickness                    0.24
#   41                         puck | halfcourt                    0.24
#   42                  quarterback | tailback                     0.24
#   43                          fox | leopard                      0.24
#   44                   pedophiles | rapists                      0.24
#   45                     potatoes | flour                        0.24
#   46                           en | el                           0.24
#   47               infrastructure | infrastructural              0.24
#   48                   evangelism | gospel                       0.24
#   49                       fiance | aunt                         0.24
#   50                     pointers | dunks                        0.24
#   51                      baseman | defensive_lineman            0.23
#   52                    pedophile | rapist                       0.23
#   53                        joked | smiled                       0.23
#   54                         beer | soft_drink                   0.23
#   55                    guitarist | singer                       0.23
#   56                     election | elections                    0.23
#   57                        snuck | sneaked                      0.23
#   58                     mobsters | gangster                     0.23
#   59                 preventative | preventive                   0.23
#   60                    wrestling | boxing                       0.23
#   61                    motorbike | taxi_driver                  0.23
#   62                     wrestler | boxer                        0.23
#   63                     aviation | civil_aviation               0.23
#   64                  grandfather | uncle                        0.23
#   65                      walleye | crappie                      0.23
#   66                   speculates | opined                       0.22
#   67                  evangelical | preachers                    0.22
#   68                   wild_pitch | ensuing_kickoff              0.22
#   69                     literate | illiterate                   0.22
#   70                        noted | lamented                     0.22
#   71                        slams | raps                         0.22
#   72                         shop | shopkeeper                   0.22
#   73                  heavyweight | welterweight                 0.22
#   74                        rider | sprinter                     0.22
#   75                     hammered | thrashed                     0.22
#   76                      screwed | messed                       0.22
#   77                   gymnastics | weightlifting                0.22
#   78                   noteworthy | worth_mentioning             0.22
#   79                     lobsters | crabs                        0.22
#   80                    taxpayers | tax_payers                   0.22
#   81                       co_ops | cooperatives                 0.22
#   82                    currently | presently                    0.22
#   83                    carpenter | laborer                      0.22
#   84                         corn | rice                         0.22
#   85                        heist | robbery                      0.21
#   86                 exhilarating | electrifying                 0.21
#   87                         wife | mother                       0.21
#   88                      affable | jovial                       0.21
#   89                    admirable | commendable                  0.21
#   90                     wetlands | marshes                      0.21
#   91                     families | relatives                    0.21
#   92                       cheese | yogurt                       0.21
#   93                   infielders | safeties                     0.21
#   94                 groin_strain | hamstring_injury             0.21
#   95                     effluent | sewerage                     0.21
#   96                   pinpointed | identified                   0.21
#   97                signal_caller | wideout                      0.21
#   98                      spooked | scared                       0.21
#   99                   uninformed | uneducated                   0.21
#  100                 quarterbacks | wide_receivers               0.21
#  101                       lineup | starting_lineup              0.21
#  102             communist_regime | dictatorship                 0.21
#  103                    netminder | striker                      0.21
#  104                 condominiums | flats                        0.21
#  105            sexual_misconduct | rape                         0.21
#  106                     backline | frontcourt                   0.21
#  107               businesspeople | businessmen                  0.21
#  108                    orchestra | singers                      0.21
#  109                       elites | rulers                       0.21
#  110                 empty_netter | free_throws                  0.21
#  111                      ballots | ballot_boxes                 0.21
#  112                     shutouts | yards_rushing                0.21
#  113                          soy | palm_oil                     0.21
#  114                    masterful | mesmerizing                  0.21
#  115                   nationwide | countrywide                  0.21
#  116                        input | inputs                       0.21
#  117                        euros | rupees                       0.21
#  118                       kroner | ringgit                      0.21
#  119                         geek | dude                         0.21
#  120                        condo | apartment_complex            0.21
#  121                     medalist | bronze_medalist              0.21
#  122                          inn | motel                        0.21
#  123                    misplayed | blocked_punt                 0.21
#  124                      lobster | shrimp                       0.21
#  125                         dads | fathers                      0.20
#  126                        Leroy | Latonya                      0.20
#  127                        geeks | dudes                        0.20
#  128                 chiropractor | doctor                       0.20
#  129                   protecting | guarding                     0.20
#  130                        urban | slums                        0.20
#  131                     boutique | hair_salon                   0.20
#  132                      herring | shad                         0.20
#  133                     blasting | blaring                      0.20
#  134              public_servants | civil_servants               0.20
#  135                    shortstop | linebacker                   0.20
#  136                   strikeouts | sacks                        0.20
#  137           misdemeanor_counts | aggravated_assault           0.20
#  138                       adults | youths                       0.20
#  139                     director | chairperson                  0.20
#  140                         monk | villager                     0.20
#  141                       errors | turnovers                    0.20
#  142                     renowned | reputed                      0.20
#  143                       argues | complains                    0.20
#  144                       Laurie | Carrie                       0.20
#  145                     renegade | rebel                        0.20
#  146                      staffer | aide                         0.20
#  147                         tram | bus                          0.20
#  148                    disrepair | dilapidated                  0.20
#  149                       swanky | posh                         0.20
#  150                      quipped | retorted                     0.20
#  151                  consultants | contractors                  0.20
#  152                  crime_spree | carjacking                   0.20
#  153                         grad | student                      0.20
#  154                felony_counts | attempted_murder             0.20
#  155                       hubris | bravado                      0.20
#  156                    simulcast | telecast                     0.20
#  157                       racing | drag_racing                  0.20
#  158                   professors | lecturers                    0.20
#  159                       noting | stressing                    0.20
#  160                      priests | clerics                      0.20
#  161                      markets | bourses                      0.20
#  162                      kickers | defensive_backs              0.20
#  163                     blustery | sweltering                   0.20
#  164                    unethical | corrupt                      0.20
#  165                   bureaucrat | civil_servant                0.20
#  166                    historian | poet                         0.20
#  167            commonly_referred | popularly_known              0.20
#  168                       studio | recording_studio             0.20
#  169                      stellar | unimpressive                 0.20
#  170                        nerdy | chubby                       0.20
#  171                   pedophilia | child_molestation            0.20
#  172                     soldiers | policemen                    0.20
#  173                         gosh | gonna                        0.19
#  174                 conservative | fundamentalist               0.19
#  175                       alpine | mountains                    0.19
#  176                      chuckle | smile                        0.19
#  177                    chuckling | smiling                      0.19
#  178             summary_judgment | appellant                    0.19
#  179                   water_polo | badminton                    0.19
#  180                  individuals | persons                      0.19
#  181                     pitching | right_hander                 0.19
#  182                  bittersweet | joyful                       0.19
#  183                       bested | outclassed                   0.19
#  184                         mojo | swagger                      0.19
#  185                         trey | dunk                         0.19
#  186                   straw_poll | primaries                    0.19
#  187                      ethanol | sugarcane                    0.19
#  188                    grandkids | grandmother                  0.19
#  189            industrialization | poverty_alleviation          0.19
#  190                     thrilled | elated                       0.19
#  191             sexually_abusing | raping                       0.19
#  192                        crook | thug                         0.19
#  193                     airplane | airliner                     0.19
#  194                    airplanes | aircrafts                    0.19
#  195                         said | saying                       0.19
#  196                         mail | courier                      0.19
#  197                       season | preseason                    0.19
#  198                       castle | palace                       0.19
#  199           mixed_martial_arts | light_heavyweight            0.19
#  200                         poke | poked                        0.19
#  201                    wrestlers | boxers                       0.19
#  202                       shacks | slum                         0.19
#  203                     staffers | aides                        0.19
#  204                        geese | migratory_birds              0.19
#  205            criminal_mischief | aggravated_robbery           0.19
#  206                    communism | imperialism                  0.19
#  207                        whore | pimp                         0.19
#  208               harness_racing | jockey                       0.19
#  209                      grandpa | mama                         0.19
#  210           multiple_sclerosis | lupus                        0.19
#  211                       punted | yard_punt                    0.19
#  212                        bouts | knockouts                    0.19
#  213                     designer | fashion_designer             0.19
#  214                     concedes | confesses                    0.19
#  215                       homily | sermon                       0.19
#  216                        storm | tropical_storm               0.19
#  217                   curriculum | curricula                    0.19
#  218                         Jill | Mary                         0.19
#  219                    suggested | intimated                    0.19
#  220                      filings | periodic_reports             0.19
#  221                   alcoholics | drug_addict                  0.19
#  222                         riff | song                         0.19
#  223                        dairy | bakery                       0.19
#  224                      advises | counsels                     0.19
#  225                  maple_syrup | honey                        0.19
#  226                      gymnast | dancer                       0.19
#  227                       hurler | southpaw                     0.19
#  228                  snowmobiles | wheelers                     0.19
#  229                  keyboardist | vocalist                     0.19
#  230                        towns | localities                   0.19
#  231                    sophomore | redshirt_freshman            0.19
#  232                 amphetamines | banned_substance             0.19
#  233                        kayak | kite                         0.19
#  234                   ecosystems | coral_reefs                  0.19
#  235                locally_grown | fresh_fruits                 0.19
#  236                   sectionals | meter_relay                  0.19
#  237                         euro | rupee                        0.19
#  238                   herbicides | fertilizers                  0.19
#  239                     standout | signee                       0.19
#  240                   conception | womb                         0.19
#  241                      e_mails | text_messages                0.19
#  242                        cadre | cadres                       0.19
#  243                  round_robin | defending_champions          0.19
#  244                       likens | depicts                      0.19
#  245                     suggests | implies                      0.19
#  246                    partisans | sympathizers                 0.19
#  247                      dentist | barber                       0.19
#  248                       crooks | gangsters                    0.19
#  249                  groundwater | potable_water                0.19
#  250                      skaters | dancers                      0.19
#  251                        cello | vocalists                    0.19
#  252                      hot_tub | bathtub                      0.19
#  253                        angst | bitterness                   0.19
#  254                         spat | quarrel                      0.19
#  255                      pumpkin | watermelon                   0.19
#  256               sacrifice_bunt | inbounds_pass                0.19
#  257                        monks | villagers                    0.19
#  258                        punts | kickoff_returns              0.19
#  259                          ski | giant_slalom                 0.18
#  260             renewable_energy | electricity                  0.18
#  261                        skill | athleticism                  0.18
#  262                   capitalism | democracy                    0.18
#  263                     sweaters | clothes                      0.18
#  264                       genius | greatness                    0.18
#  265                 homelessness | poverty                      0.18
#  266           infectious_disease | dengue                       0.18
#  267                        rural | poverty_stricken             0.18
#  268                      outshot | outrebounded                 0.18
#  269                     magician | entertainer                  0.18
#  270             undecided_voters | superdelegates               0.18
#  271                          del | da                           0.18
#  272                        lingo | slang                        0.18
#  273                 enthusiastic | energetic                    0.18
#  274                          ads | promos                       0.18
#  275                  referencing | reference                    0.18
#  276              civil_liberties | civil_rights                 0.18
#  277                   extremists | militant                     0.18
#  278                     cottages | bungalows                    0.18
#  279                   downsizing | retrenchment                 0.18
#  280                      fascism | colonialism                  0.18
#  281                    scoreless | foul_trouble                 0.18
#  282                     organist | hymns                        0.18
#  283                   disastrous | horrid                       0.18
#  284                     diocesan | parish                       0.18
#  285                   discipline | indiscipline                 0.18
#  286                    perplexed | bewildered                   0.18
#  287                           im | thats                        0.18
#  288                     thinkers | intellectuals                0.18
#  289                      likened | resembled                    0.18
#  290                    classmate | younger_brother              0.18
#  291               drunken_driver | motorist                     0.18
#  292                    explained | clarified                    0.18
#  293                           ag | agriculture                  0.18
#  294                        beers | rum                          0.18
#  295                        fraud | corruption                   0.18
#  296                drunk_driving | reckless_driving             0.18
#  297                   renovation | beautification               0.18
#  298                  floundering | languishing                  0.18
#  299                    asparagus | eggplant                     0.18
#  300                   wind_farms | hydropower                   0.18
#  301                    fireworks | firecrackers                 0.18
#  302                   geographic | geographical                 0.18
#  303                      cottage | bungalow                     0.18
#  304                   enthusiasm | joy                          0.18
#  305                    continual | continuous                   0.18
#  306                     ice_rink | swimming_pool                0.18
#  307                       bistro | eatery                       0.18
#  308                     hopefuls | aspirants                    0.18
#  309                  monasteries | temples                      0.18
#  310                     explains | informs                      0.18
#  311                        vodka | fruit_juice                  0.18
#  312                       pretty | alright                      0.18
#  313                       admits | confessed                    0.18
#  314                       anyhow | dont                         0.18
#  315                         wine | liquor                       0.18
#  316                      besting | beating                      0.18
#  317                     ambiance | ambience                     0.18
#  318                        moron | bitch                        0.18
#  319                         team | squad                        0.18
#  320                    concludes | concluding                   0.18
#  321                  pornography | prostitution                 0.18
#  322                    egregious | glaring                      0.18
#  323                        riffs | rhythms                      0.18
#  324                     conflict | bloodshed                    0.18
#  325                       boiler | air_conditioner              0.18
#  326                        shots | shooting                     0.18
#  327                       superb | scintillating                0.18
#  328                      goalies | offensive_linemen            0.18
#  329                     observes | observed                     0.18
#  330                     refining | petrochemicals               0.18
#  331                  voter_fraud | vote_rigging                 0.18
#  332                      linkage | linkages                     0.18
#  333                 totalitarian | democratic                   0.18
#  334                  continually | continuously                 0.18
#  335             enemy_combatants | enemy_combatant              0.18
#  336                       rabbis | imams                        0.18
#  337                    curveball | mph_fastball                 0.18
#  338                          art | artists                      0.18
#  339                       anyway | wont                         0.18
#  340                mean_spirited | racist                       0.18
#  341                       astute | skilful                      0.18
#  342                  broken_ribs | bruises                      0.18
#  343                        yacht | cargo_ship                   0.18
#  344                    bandmates | album                        0.18
#  345                 screenwriter | film                         0.18
#  346                       expats | expatriates                  0.18
#  347                       whites | blacks                       0.17
#  348                   alcoholism | drug_addiction               0.17
#  349                   bicyclists | pedestrian                   0.17
#  350                 bloop_single | putback                      0.17
#  351                         says | insists                      0.17
#  352                   blond_hair | brown_eyes                   0.17
#  353                          pig | chicken                      0.17
#  354                    spaghetti | macaroni                     0.17
#  355                     denizens | environs                     0.17
#  356                     advocacy | non_governmental             0.17
#  357                         pigs | poultry                      0.17
#  358                          red | white                        0.17
#  359                     economic | socio_economic               0.17
#  360                       wheels | rims                         0.17
#  361                     vineyard | orchard                      0.17
#  362                     chuckled | cried                        0.17
#  363                      assists | rpg                          0.17
#  364                 approachable | talkative                    0.17
#  365                  persecution | marginalization              0.17
#  366                  goaltending | backcourt                    0.17
#  367                         moms | mothers                      0.17
#  368                        until | till                         0.17
#  369                      bowling | fast_bowler                  0.17
#  370                 rotator_cuff | quadriceps                   0.17
#  371                serial_killer | murder                       0.17
#  372                reprehensible | inhuman                      0.17
#  373                      wingers | strikers                     0.17
#  374                  aptly_named | nicknamed                    0.17
#  375                       repaid | disbursed                    0.17
#  376                        prose | poetry                       0.17
#  377                        hopes | hope                         0.17
#  378                      disdain | disrespect                   0.17
#  379                          van | minibus                      0.17
#  380                       rhymes | rap                          0.17
#  381                            c | b                            0.17
#  382                   collegiate | college                      0.17
#  383                     solitude | tranquility                  0.17
#  384              facial_injuries | gunshot_wounds               0.17
#  385                       winger | playmaker                    0.17
#  386                     imploded | crumbled                     0.17
#  387                      fiancee | brother                      0.17
#  388                        urges | exhorted                     0.17
#  389                     halfback | nose_tackle                  0.17
#  390                         meth | crack_cocaine                0.17
#  391                    synagogue | mosque                       0.17
#  392                     pastoral | spiritual                    0.17
#  393                       abuses | brutality                    0.17
#  394                    broadband | landline                     0.17
#  395                        scrum | flanker                      0.17
#  396                   conjecture | speculations                 0.17
#  397             sexual_predators | felons                       0.17
#  398                 wine_tasting | barbeque                     0.17
#  399                         deli | convenience_store            0.17
#  400                     sanitary | sanitation                   0.17
#  401                        goals | points                       0.17
#  402                    regionals | semi_finals                  0.17
#  403                sex_offenders | parolees                     0.17
#  404                    pseudonym | alias                        0.17
#  405                    brilliant | dazzling                     0.17
#  406                     trespass | criminal_trespass            0.17
#  407                        soggy | humid                        0.17
#  408                    inaugural | inauguration                 0.17
#  409                      rabbits | tigers                       0.17
#  410                    chauffeur | cab_driver                   0.17
#  411                      innings | overs                        0.17
#  412                    oil_sands | oilfield                     0.17
#  413                      village | locality                     0.17
#  414            complaint_alleges | indictment_alleges           0.17
#  415                    shale_gas | hydrocarbons                 0.17
#  416                     raw_milk | milk                         0.17
#  417                      anxiety | hopelessness                 0.17
#  418                      trolley | taxi                         0.17
#  419                    investors | traders                      0.17
#  420                     sickened | killed                       0.17
#  421              sexually_abused | raped                        0.17
#  422                 constituents | constituency                 0.17
#  423                        skier | athlete                      0.17
#  424                     heritage | cultural_heritage            0.17
#  425                      cheeses | breads                       0.17
#  426                    producers | importers                    0.17
#  427                        farms | plantations                  0.17
#  428                   dissidents | exiles                       0.17
#  429                    merchants | shopkeepers                  0.17
#  430                       skiers | athletes                     0.17
#  431                      jailing | detaining                    0.17
#  432                   cul_de_sac | neighborhood                 0.17
#  433                       design | styling                      0.17
#  434                     lacrosse | football                     0.17
#  435                   department | directorate                  0.17
#  436                    piecemeal | haphazard                    0.17
#  437                counterattack | attack                       0.17
#  438                      atheist | religious                    0.17
#  439                  departments | ministries                   0.16
#  440                      reckons | reckon                       0.16
#  441                    hypocrisy | racism                       0.16
#  442                      spouses | dependents                   0.16
#  443                    colleague | comrade                      0.16
#  444                inappropriate | indecent                     0.16
#  445                        poker | bingo                        0.16
#  446                   thoughtful | gentle                       0.16
#  447                      scarves | headscarf                    0.16
#  448                ramifications | repercussions                0.16
#  449                       clerks | cashier                      0.16
#  450                        rifle | pistol                       0.16
#  451                     travesty | injustice                    0.16
#  452                 conservatism | fundamentalism               0.16
#  453                        barbs | taunts                       0.16
#  454                   townhouses | storey                       0.16
#  455                     trombone | saxophone                    0.16
#  456                    chastised | scolded                      0.16
#  457                        mused | talked                       0.16
#  458                      officer | policeman                    0.16
#  459                     flooding | flash_floods                 0.16
#  460                    miniscule | paltry                       0.16
#  461                       battle | fight                        0.16
#  462                     ordained | pastor                       0.16
#  463                        folks | fellas                       0.16
#  464                      parties | factions                     0.16
#  465                   wastewater | sewage                       0.16
#  466                       riders | sprinters                    0.16
#  467                    postcards | leaflets                     0.16
#  468           venture_capitalist | entrepreneur                 0.16
#  469                    headwinds | downside_risks               0.16
#  470              hotly_contested | contested                    0.16
#  471                       meadow | bushes                       0.16
#  472                     populist | nationalist                  0.16
#  473              insider_trading | bribery                      0.16
#  474                        twice | thrice                       0.16
#  475                      mussels | catfish                      0.16
#  476                    chocolate | sugar                        0.16
#  477                         ahem | uh                           0.16
#  478                       ripped | tore                         0.16
#  479                   centennial | commemoration                0.16
#  480                        cramp | cramps                       0.16
#  481                       winery | bottling                     0.16
#  482                    vineyards | orchards                     0.16
#  483                   personable | soft_spoken                  0.16
#  484                     lavender | fragrant                     0.16
#  485                   rib_injury | sprained_ankle               0.16
#  486                         bars | nightclubs                   0.16
#  487            potentially_fatal | fatal                        0.16
#  488                    bicycling | bicycle                      0.16
#  489                     consists | comprises                    0.16
#  490                   pine_trees | palm_trees                   0.16
#  491                     terrific | decent                       0.16
#  492                  defensively | rebounder                    0.16
#  493            wireless_carriers | telecom_operators            0.16
#  494                          ing | ma                           0.16
#  495                    flavorful | spicy                        0.16
#  496                   read_aloud | recited                      0.16
#  497                   backhander | floater                      0.16
#  498                      matches | dayers                       0.16
#  499             incomprehensible | senseless                    0.16

# %% [markdown]
# ### Step 7: Analyzing racial bias in word vectors asscoiated with professions
#
# Similar to Step 4, we project occpurations onto the racial dimension.

# %%
# profession analysis racial
sp = sorted([(E.v(w).dot(v_racial), w) for w in profession_words])

sp[0:20], sp[-20:]
# Out:
# ([(-0.3154624, 'artiste'),
#   (-0.27369624, 'shopkeeper'),
#   (-0.27285585, 'taxi_driver'),
#   (-0.24248752, 'cab_driver'),
#   (-0.230962, 'preacher'),
#   (-0.21709058, 'boxer'),
#   (-0.20973533, 'laborer'),
#   (-0.20361684, 'barber'),
#   (-0.19625023, 'cleric'),
#   (-0.182731, 'bodyguard'),
#   (-0.18250425, 'gangster'),
#   (-0.1816296, 'singer'),
#   (-0.16877083, 'maid'),
#   (-0.16871038, 'entertainer'),
#   (-0.16197538, 'cabbie'),
#   (-0.15332887, 'housewife'),
#   (-0.14839593, 'civil_servant'),
#   (-0.14115773, 'policeman'),
#   (-0.13648951, 'minister'),
#   (-0.1329656, 'drug_addict')],
#  [(0.087792546, 'organist'),
#   (0.09007451, 'philanthropist'),
#   (0.09135293, 'cinematographer'),
#   (0.093180254, 'manager'),
#   (0.09358391, 'investment_banker'),
#   (0.096878394, 'professor_emeritus'),
#   (0.097828984, 'curator'),
#   (0.09864862, 'freelance_writer'),
#   (0.09917156, 'programmer'),
#   (0.10142014, 'screenwriter'),
#   (0.10198846, 'author'),
#   (0.10438656, 'inventor'),
#   (0.106778406, 'adventurer'),
#   (0.10964738, 'naturalist'),
#   (0.1108993, 'planner'),
#   (0.113417216, 'historian'),
#   (0.12044048, 'adjunct_professor'),
#   (0.13106447, 'director'),
#   (0.14140993, 'consultant'),
#   (0.14241575, 'architect')])

# %% [markdown]
# ## Exercise
#
# Repeat Step 2-4 with debiased word embedding.
#
# You can use debiaswe debias function to do the debiasing with word sets of your choosing
#
# You can leave equalize_pairs and gender_specific_words blank when coming up with your own groups. We give an example for the case of gender below for you to warm up.

# %%
from debiaswe.debias import hard_debias

hard_debias(E, gender_specific_words, defs, equalize_pairs)
# Out:
# 26423 words of dimension 300 : in, for, that, is, ..., Jay, Leroy, Brad, Jermaine
# 26423 words of dimension 300 : in, for, that, is, ..., Jay, Leroy, Brad, Jermaine

# %%
# save hard-debiased embeddings

E.save('./embeddings/w2v_gnews_small_hard_debiased.txt')
# E.save('./embeddings/GoogleNews-vectors-negative300_hard_debiased.bin')
# Out:
# Wrote 26423 words to ./embeddings/w2v_gnews_small_hard_debiased.txt

# %%
# profession analysis gender
sp_debiased = sorted([(E.v(w).dot(v_gender), w) for w in profession_words])

sp_debiased[0:20], sp_debiased[-20:]
# Out:
# ([(-0.43325216, 'businessman'),
#   (-0.42799938, 'congressman'),
#   (-0.3652529, 'dad'),
#   (-0.35791722, 'councilman'),
#   (-0.22225755, 'statesman'),
#   (-0.15711337, 'salesman'),
#   (-0.10675365, 'handyman'),
#   (-0.08172014, 'monk'),
#   (-7.264316e-08, 'skipper'),
#   (-4.2375177e-08, 'comedian'),
#   (-3.7252903e-08, 'cameraman'),
#   (-3.7252903e-08, 'jeweler'),
#   (-3.3527613e-08, 'architect'),
#   (-3.3527613e-08, 'restaurateur'),
#   (-3.0733645e-08, 'promoter'),
#   (-2.9336661e-08, 'captain'),
#   (-2.8871e-08, 'economics_professor'),
#   (-2.7939677e-08, 'artiste'),
#   (-2.7939677e-08, 'strategist'),
#   (-2.6077032e-08, 'mechanic')],
#  [(3.0035153e-08, 'superintendent'),
#   (3.0733645e-08, 'comic'),
#   (3.0733645e-08, 'warden'),
#   (3.1664968e-08, 'provost'),
#   (3.3527613e-08, 'singer'),
#   (3.7252903e-08, 'correspondent'),
#   (3.7252903e-08, 'paralegal'),
#   (3.7718564e-08, 'fisherman'),
#   (3.9115548e-08, 'lecturer'),
#   (3.9115548e-08, 'registered_nurse'),
#   (4.0978193e-08, 'hairdresser'),
#   (5.5879354e-08, 'socialite'),
#   (5.9604645e-08, 'homemaker'),
#   (0.2606187, 'ballerina'),
#   (0.26477972, 'nun'),
#   (0.27208692, 'maid'),
#   (0.2965596, 'waitress'),
#   (0.37843493, 'housewife'),
#   (0.37881425, 'actress'),
#   (0.43325222, 'businesswoman')])

# %%
# analogies gender
a_gender_debiased = E.best_analogies_dist_thresh(v_gender)
we.viz(a_gender_debiased)

# for (a,b,c) in a_gender_debiased:
#     print(a+"-"+b)
we.viz(a_gender_debiased)
# Out:
# Computing neighbors
# Mean: 10.218597434053665
# Median: 7.0
# (135003, 300)
#    0                      females | males                        1.0
#    1                     sorority | fraternity                   1.0
#    2                    daughters | sons                         1.0
#    3                       female | male                         1.0
#    4                       mother | father                       1.0
#    5                     princess | prince                       1.0
#    6                        girls | boys                         1.0
#    7                 councilwoman | councilman                   1.0
#    8                         aunt | uncle                        1.0
#    9                          mom | dad                          1.0
#   10                      grandma | grandpa                      1.0
#   11                congresswoman | congressman                  1.0
#   12                        woman | man                          1.0
#   13                   motherhood | fatherhood                   1.0
#   14                          her | his                          1.0
#   15                 ex_boyfriend | ex_girlfriend                1.0
#   16                     husbands | wives                        1.0
#   17                  spokeswoman | spokesman                    1.0
#   18                        niece | nephew                       1.0
#   19                   chairwoman | chairman                     1.0
#   20                granddaughter | grandson                     1.0
#   21                  grandmother | grandfather                  1.0
#   22               ovarian_cancer | prostate_cancer              1.0
#   23                         mare | gelding                      1.0
#   24                     estrogen | testosterone                 1.0
#   25                          she | he                           1.0
#   26                businesswoman | businessman                  1.0
#   27                         girl | boy                          1.0
#   28                         gals | dudes                        1.0
#   29                      mothers | fathers                      1.0
#   30                        queen | king                         0.99
#   31               granddaughters | grandsons                    0.99
#   32                       sister | brother                      0.99
#   33                       queens | kings                        0.99
#   34                       ladies | gentlemen                    0.99
#   35                      sisters | brothers                     0.99
#   36                   schoolgirl | schoolboy                    0.99
#   37                  twin_sister | twin_brother                 0.99
#   38                        filly | colt                         0.99
#   39                      herself | himself                      0.99
#   40                     daughter | son                          0.99
#   41                      convent | monastery                    0.99
#   42                        women | men                          0.99
#   43                         moms | dads                         0.99
#   44                      actress | actor                        0.64
#   45                          gal | dude                         0.61
#   46                      lesbian | gay                          0.54
#   47                   compatriot | countryman                   0.52
#   48                      husband | younger_brother              0.51
#   49                      heroine | protagonist                  0.49
#   50                    actresses | actors                       0.48
#   51                    housewife | homemaker                    0.43
#   52                     waitress | waiter                       0.43
#   53                        aunts | uncles                       0.42
#   54                     feminism | feminist                     0.42
#   55                     mustache | beard                        0.42
#   56                         hers | theirs                       0.41
#   57                          kid | guy                          0.40
#   58                        fella | gentleman                    0.39
#   59                       nieces | nephews                      0.39
#   60                teenage_girls | teenagers                    0.39
#   61                          nun | monk                         0.38
#   62                 stepdaughter | stepson                      0.38
#   63                    childhood | boyhood                      0.38
#   64                        mommy | daddy                        0.37
#   65                           me | him                          0.37
#   66                      goddess | god                          0.36
#   67                       viagra | cialis                       0.36
#   68                         diva | superstar                    0.36
#   69                      fillies | colts                        0.36
#   70                       brides | bridal                       0.35
#   71                    matriarch | patriarch                    0.35
#   72                         maid | housekeeper                  0.35
#   73                      hostess | bartender                    0.34
#   74                       vagina | penis                        0.33
#   75                         mama | fella                        0.33
#   76                 teenage_girl | teenager                     0.32
#   77                   stepmother | eldest_son                   0.31
#   78                    ballerina | dancer                       0.30
#   79                    maternity | midwives                     0.30
#   80                 grandmothers | grandparents                 0.30
#   81                  compatriots | countrymen                   0.29
#   82                        witch | witchcraft                   0.29
#   83                    boyfriend | stepfather                   0.29
#   84                       uterus | intestine                    0.28
#   85                    menopause | puberty                      0.28
#   86                      heiress | socialite                    0.28
#   87                        bride | wedding                      0.28
#   88                     lesbians | gays                         0.27
#   89                       eldest | elder_brother                0.27
#   90                   politician | statesman                    0.25
#   91                        maids | servants                     0.24
#   92                     dictator | strongman                    0.24
#   93                    youngster | lad                          0.24
#   94                         nuns | priests                      0.24
#   95                     maternal | infant_mortality             0.24
#   96                        hubby | pal                          0.23
#   97                       blokes | bloke                        0.22
#   98                         lady | waitress                     0.21
#   99                      soprano | baritone                     0.21
#  100                  girlfriends | buddies                      0.21
#  101                   boyfriends | girlfriend                   0.20
#  102                  facial_hair | beards                       0.19
#  103                         womb | fetus                        0.18
#  104               businesspeople | businessmen                  0.18
#  105                       fiance | roommate                     0.18
#  106                         beau | lover                        0.18
#  107                  salesperson | salesman                     0.18
#  108                      witches | vampires                     0.18
#  109            estranged_husband | estranged                    0.17
#  110                 counterparts | brethren                     0.16
#  111                      bastard | chap                         0.16
#  112                        widow | deceased                     0.16
#  113                   obstetrics | pediatrics                   0.16
#  114                 spokespeople | spokesmen                    0.16
#  115                   friendship | brotherhood                  0.15
#  116                         hens | chickens                     0.15
#  117                          hen | cock                         0.15
#  118                      replied | sir                          0.14
#  119                        colon | prostate                     0.14
#  120                     mistress | prostitute                   0.14
#  121                     stallion | stud                         0.13
#  122                        manly | macho                        0.13
#  123                         wife | cousin                       0.13
#  124                           ma | na                           0.13
#  125                    carpenter | handyman                     0.12
#  126                        bulls | bull                         0.12
#  127                       widows | families                     0.11
#  128                  salespeople | salesmen                     0.10
#  129                   girlfriend | friend                       0.10
#  130                       suitor | takeover_bid                 0.09
#  131                       gaffer | lads                         0.09
#  132                        semen | saliva                       0.09
#  133                    elephants | lions                        0.09
#  134                      suitors | bidders                      0.08
#  135                      fiancee | married                      0.08
#  136                         guys | fellas                       0.08
#  137                   hair_salon | barbershop                   0.07
#  138                     elephant | lion                         0.05
#  139                        colts | mares                        0.05
#  140                           pa | mo                           0.05
#  141                        footy | blokes                       0.04
#  142                     aldermen | councilmen                   0.04
#  143                        monks | monasteries                  0.04
#  144                      widower | widowed                      0.03
#  145                     bachelor | bachelor_degree              0.02
#  146                        sperm | embryos                      0.02
#  147                         deer | elk                          0.02
#  148              residence_halls | fraternities                 0.01
#  149                      wedlock | fathered                     0.01
#  150                        penis | genitals                     0.00
#  151                      princes | royals                       0.00
#    0                      females | males                        1.0
#    1                     sorority | fraternity                   1.0
#    2                    daughters | sons                         1.0
#    3                       female | male                         1.0
#    4                       mother | father                       1.0
#    5                     princess | prince                       1.0
#    6                        girls | boys                         1.0
#    7                 councilwoman | councilman                   1.0
#    8                         aunt | uncle                        1.0
#    9                          mom | dad                          1.0
#   10                      grandma | grandpa                      1.0
#   11                congresswoman | congressman                  1.0
#   12                        woman | man                          1.0
#   13                   motherhood | fatherhood                   1.0
#   14                          her | his                          1.0
#   15                 ex_boyfriend | ex_girlfriend                1.0
#   16                     husbands | wives                        1.0
#   17                  spokeswoman | spokesman                    1.0
#   18                        niece | nephew                       1.0
#   19                   chairwoman | chairman                     1.0
#   20                granddaughter | grandson                     1.0
#   21                  grandmother | grandfather                  1.0
#   22               ovarian_cancer | prostate_cancer              1.0
#   23                         mare | gelding                      1.0
#   24                     estrogen | testosterone                 1.0
#   25                          she | he                           1.0
#   26                businesswoman | businessman                  1.0
#   27                         girl | boy                          1.0
#   28                         gals | dudes                        1.0
#   29                      mothers | fathers                      1.0
#   30                        queen | king                         0.99
#   31               granddaughters | grandsons                    0.99
#   32                       sister | brother                      0.99
#   33                       queens | kings                        0.99
#   34                       ladies | gentlemen                    0.99
#   35                      sisters | brothers                     0.99
#   36                   schoolgirl | schoolboy                    0.99
#   37                  twin_sister | twin_brother                 0.99
#   38                        filly | colt                         0.99
#   39                      herself | himself                      0.99
#   40                     daughter | son                          0.99
#   41                      convent | monastery                    0.99
#   42                        women | men                          0.99
#   43                         moms | dads                         0.99
#   44                      actress | actor                        0.64
#   45                          gal | dude                         0.61
#   46                      lesbian | gay                          0.54
#   47                   compatriot | countryman                   0.52
#   48                      husband | younger_brother              0.51
#   49                      heroine | protagonist                  0.49
#   50                    actresses | actors                       0.48
#   51                    housewife | homemaker                    0.43
#   52                     waitress | waiter                       0.43
#   53                        aunts | uncles                       0.42
#   54                     feminism | feminist                     0.42
#   55                     mustache | beard                        0.42
#   56                         hers | theirs                       0.41
#   57                          kid | guy                          0.40
#   58                        fella | gentleman                    0.39
#   59                       nieces | nephews                      0.39
#   60                teenage_girls | teenagers                    0.39
#   61                          nun | monk                         0.38
#   62                 stepdaughter | stepson                      0.38
#   63                    childhood | boyhood                      0.38
#   64                        mommy | daddy                        0.37
#   65                           me | him                          0.37
#   66                      goddess | god                          0.36
#   67                       viagra | cialis                       0.36
#   68                         diva | superstar                    0.36
#   69                      fillies | colts                        0.36
#   70                       brides | bridal                       0.35
#   71                    matriarch | patriarch                    0.35
#   72                         maid | housekeeper                  0.35
#   73                      hostess | bartender                    0.34
#   74                       vagina | penis                        0.33
#   75                         mama | fella                        0.33
#   76                 teenage_girl | teenager                     0.32
#   77                   stepmother | eldest_son                   0.31
#   78                    ballerina | dancer                       0.30
#   79                    maternity | midwives                     0.30
#   80                 grandmothers | grandparents                 0.30
#   81                  compatriots | countrymen                   0.29
#   82                        witch | witchcraft                   0.29
#   83                    boyfriend | stepfather                   0.29
#   84                       uterus | intestine                    0.28
#   85                    menopause | puberty                      0.28
#   86                      heiress | socialite                    0.28
#   87                        bride | wedding                      0.28
#   88                     lesbians | gays                         0.27
#   89                       eldest | elder_brother                0.27
#   90                   politician | statesman                    0.25
#   91                        maids | servants                     0.24
#   92                     dictator | strongman                    0.24
#   93                    youngster | lad                          0.24
#   94                         nuns | priests                      0.24
#   95                     maternal | infant_mortality             0.24
#   96                        hubby | pal                          0.23
#   97                       blokes | bloke                        0.22
#   98                         lady | waitress                     0.21
#   99                      soprano | baritone                     0.21
#  100                  girlfriends | buddies                      0.21
#  101                   boyfriends | girlfriend                   0.20
#  102                  facial_hair | beards                       0.19
#  103                         womb | fetus                        0.18
#  104               businesspeople | businessmen                  0.18
#  105                       fiance | roommate                     0.18
#  106                         beau | lover                        0.18
#  107                  salesperson | salesman                     0.18
#  108                      witches | vampires                     0.18
#  109            estranged_husband | estranged                    0.17
#  110                 counterparts | brethren                     0.16
#  111                      bastard | chap                         0.16
#  112                        widow | deceased                     0.16
#  113                   obstetrics | pediatrics                   0.16
#  114                 spokespeople | spokesmen                    0.16
#  115                   friendship | brotherhood                  0.15
#  116                         hens | chickens                     0.15
#  117                          hen | cock                         0.15
#  118                      replied | sir                          0.14
#  119                        colon | prostate                     0.14
#  120                     mistress | prostitute                   0.14
#  121                     stallion | stud                         0.13
#  122                        manly | macho                        0.13
#  123                         wife | cousin                       0.13
#  124                           ma | na                           0.13
#  125                    carpenter | handyman                     0.12
#  126                        bulls | bull                         0.12
#  127                       widows | families                     0.11
#  128                  salespeople | salesmen                     0.10
#  129                   girlfriend | friend                       0.10
#  130                       suitor | takeover_bid                 0.09
#  131                       gaffer | lads                         0.09
#  132                        semen | saliva                       0.09
#  133                    elephants | lions                        0.09
#  134                      suitors | bidders                      0.08
#  135                      fiancee | married                      0.08
#  136                         guys | fellas                       0.08
#  137                   hair_salon | barbershop                   0.07
#  138                     elephant | lion                         0.05
#  139                        colts | mares                        0.05
#  140                           pa | mo                           0.05
#  141                        footy | blokes                       0.04
#  142                     aldermen | councilmen                   0.04
#  143                        monks | monasteries                  0.04
#  144                      widower | widowed                      0.03
#  145                     bachelor | bachelor_degree              0.02
#  146                        sperm | embryos                      0.02
#  147                         deer | elk                          0.02
#  148              residence_halls | fraternities                 0.01
#  149                      wedlock | fathered                     0.01
#  150                        penis | genitals                     0.00
#  151                      princes | royals                       0.00
